# %% [markdown]
# #**HW 2: Optimize and train Deep Models**
#
# In this homework, we will explore how to develop a simple Deep Neural Network for image classification. We will explore two common libraries: TensorFlow and Keras.
# Then we will explore how to face a well know problem that is common to encounter during the training phase: the Overfitting.
# Finally, we will study how to perform a fair model selection.
# Hint: Before starting the exercise take a look at how Tensorflow and Keras are designed.

# %% [markdown]
# ##Exercise 2.1: Image Classficiation with Tensorflow and Keras
#
# In this first exercise we will develop a 3 layer Neural Network to perfrom image classification.
#
# Let's start importing the libraries we will need and setting a couple of environmental variables.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sklearn
import sys
import tensorflow as tf
from tensorflow import keras  # tf.keras
import time

#Set the log level in order to hide the unuseful warnings
import logging
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3" 

tf.random.set_seed(42)

# %% [markdown]
# ### Load Data: Fashion MNIST dataset
#
# We will use the Fashion MNIST dataset, a dataset of Zalando's articles. Each sample is a 28x28 pixels grayscale image, associated with a label from 10 classes:
#
# class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]
#
# Each pixel intensity is represented by a uint8 (byte) from 0 to 255.
# We will divide the dataset in training, testing and validation set. As you already know, the training set will be used to train the model, the validation set will be used to perform model selection and finally, the test set will be used to asses the performance of deep network.

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = (
    fashion_mnist.load_data()) #The dataset is already divede in test and training...

#We extract the first 5000 samples of the training set, to use them as the validation set
X_valid, X_train = X_train_full[:5000], X_train_full[5000:] 
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %% [markdown]
# Let's take a look at a sample of the images in the dataset:

# %%
n_rows = 5
n_cols = 10
plt.figure(figsize=(n_cols*1.4, n_rows * 1.6))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train[index], cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(class_names[y_train[index]])
plt.show()

# %% [markdown]
# ### Define the model:
#
# Let's build a Sequential model (keras.models.Sequential) and add four layers to it by calling its add() method:
#
#
# *  we start with a Flatten layer (keras.layers.Flatten) to convert each 28x28 image to a single row of 784 pixel values. Since it is the first layer in your model, you should specify the input_shape argument, leaving out the batch size: [28, 28];
# *  a Dense layer (keras.layers.Dense) with 300 neurons, and the "relu" activation function;
# * another Dense layer with 100 neurons, also with the "relu" activation function;
# * a final Dense layer with 10 output neurons (one per class), and with the "softmax" activation function to ensure that the sum of all the estimated class probabilities for each image is equal to 1.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
model.add(keras.layers.Dense(300, activation="relu"))
model.add(keras.layers.Dense(100, activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))

# %% [markdown]
# Call the model's summary() method to check if the model has been built correctly. Also, try using keras.utils.plot_model() to save an image of your model's architecture.

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_6 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 300)               235500
# _________________________________________________________________
# dense_19 (Dense)             (None, 100)               30100
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model, "my_mnist_model.png", show_shapes=True)

# %% [markdown]
# As you can see, the first dimension of each layer is not defined (?), indeed this dimension in each layer is variable and depends on the batch size.

# %% [markdown]
# ### Optimize the model:
#
# After the model has been created, you must call its compile() method to specify the loss function and the optimizer to use.
#
# The conventional way is to have the target outputs to match the output shape. In this case that would mean to convert the targets to the one-hot encoded array to match with the output shape.
# However, with the help of the sparse_categorical_crossentropy loss function, we can skip that step and keep the integers as targets.
#
#  In this case, we want to use the "sparse_categorical_crossentropy" loss, and the SGD optimizer (stochastic gradient descent).
#
#
#
# Moreover, you can optionally specify a list of additional metrics that should be measured during training. In this case we specify metrics=["accuracy"].

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=1e-3),
              metrics=["accuracy"])

# %% [markdown]
# Now our model is ready to be trained. Call its fit() method, passing to it the input features (X_train) and the target classes (y_train). Set the number of epoch to 20.
# In order to validate our model we will also pass the validation data by setting validation_data=(X_valid, y_valid). Keras will compute the loss and the additional metrics (the accuracy in this case) on the validation set at the end of each epoch. If the loss on the training set is much lower than the one on the validation set, your model is probably overfitting the training set. Note: the fit() method will return a History object containing training stats.

# %%
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 2.4610 - accuracy: 0.7195 - val_loss: 0.6724 - val_accuracy: 0.7664
# Epoch 2/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5560 - accuracy: 0.7993 - val_loss: 0.5232 - val_accuracy: 0.8206
# Epoch 3/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4885 - accuracy: 0.8192 - val_loss: 0.5421 - val_accuracy: 0.8116
# Epoch 4/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4534 - accuracy: 0.8325 - val_loss: 0.4822 - val_accuracy: 0.8244
# Epoch 5/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4294 - accuracy: 0.8409 - val_loss: 0.4510 - val_accuracy: 0.8422
# Epoch 6/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4113 - accuracy: 0.8475 - val_loss: 0.4634 - val_accuracy: 0.8450
# Epoch 7/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3966 - accuracy: 0.8532 - val_loss: 0.4514 - val_accuracy: 0.8470
# Epoch 8/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3858 - accuracy: 0.8562 - val_loss: 0.4767 - val_accuracy: 0.8364
# Epoch 9/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3742 - accuracy: 0.8606 - val_loss: 0.4331 - val_accuracy: 0.8504
# Epoch 10/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3653 - accuracy: 0.8643 - val_loss: 0.4286 - val_accuracy: 0.8558
# Epoch 11/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3564 - accuracy: 0.8663 - val_loss: 0.4188 - val_accuracy: 0.8606
# Epoch 12/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3499 - accuracy: 0.8693 - val_loss: 0.4217 - val_accuracy: 0.8580
# Epoch 13/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3427 - accuracy: 0.8709 - val_loss: 0.4269 - val_accuracy: 0.8574
# Epoch 14/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3383 - accuracy: 0.8734 - val_loss: 0.4341 - val_accuracy: 0.8548
# Epoch 15/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3307 - accuracy: 0.8756 - val_loss: 0.4137 - val_accuracy: 0.8640
# Epoch 16/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3272 - accuracy: 0.8782 - val_loss: 0.4233 - val_accuracy: 0.8628
# Epoch 17/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3232 - accuracy: 0.8792 - val_loss: 0.4339 - val_accuracy: 0.8562
# Epoch 18/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3169 - accuracy: 0.8805 - val_loss: 0.4270 - val_accuracy: 0.8652
# Epoch 19/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3128 - accuracy: 0.8829 - val_loss: 0.4121 - val_accuracy: 0.8688
# Epoch 20/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3082 - accuracy: 0.8839 - val_loss: 0.4244 - val_accuracy: 0.8594

# %% [markdown]
# Let's plot the loss and the accuracy trends on both training and validation sets. We define the "plot_learning_curves" because we will reuse it in the next steps.

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 1)
    plt.show()
plot_learning_curves(history)

# %% [markdown]
# ### Evaluate the model:
#
# Now, our model has been optimized on the training set, and as you can see the performance on the validation set in quite similar (so it does not overfit the training data). Let's now evaluate the performance of our model using the test set.

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 0s 2ms/step - loss: 0.4747 - accuracy: 0.8357
# [0.4746619760990143, 0.8356999754905701]

# %% [markdown]
# ### Input normalization:
#
# When using Gradient Descent, it is usually a good idea to ensure that all the features have a similar scale. It's a common practice to scale your data inputs to have zero mean and unit variance. This is known as the standard scaler approach.
# Try to standardize the pixel values and see if this improves the performance of your neural network.

# %%
###########################################################################
#It would be problematic to feed a neural network values that employ such different scales of values. 
#The network can also adapt to such heterogeneous data, but learning would be much more difficult. 
#A widely used best practice for considering such disparate data is to apply normalization to it. 
#For each characteristic in the input data, you subtract the average of the characteristic 
#and divide it by the standard deviation, so that the characteristic is centered on 0 and has a unitary standard deviation. 

mean = X_train.mean(axis=0)
std = X_train.std(axis=0) 

X_train_scaled = (X_train - mean) / std 
X_valid_scaled = (X_valid - mean) / std
X_test_scaled = (X_test - mean) / std
#############################################################################
#Another method that I used is, before the training, 
#we pre-process the data by reconfiguring it in the form expected by the network and scaling it so that all values are within the range [0.1].

#X_train_scaled = X_train.astype('float32') /255
#X_valid_scaled = X_valid.astype('float32') /255
#X_test_scaled = X_test.astype('float32') /255



#Alternatively, you can use Scikit-Learn's StandardScaler...

# %% [markdown]
# Let's define the model in order to re-initialize the weights and then train it by using the normalize data.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
model.add(keras.layers.Dense(300, activation="relu"))
model.add(keras.layers.Dense(100, activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=1e-3),
              metrics=["accuracy"])

history = model.fit(X_train_scaled, y_train, epochs=20,
                    validation_data=(X_valid_scaled, y_valid))
print("Model Evaluation")
model.evaluate(X_test_scaled, y_test)
plot_learning_curves(history)
# Out:
# Epoch 1/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.9390 - accuracy: 0.6949 - val_loss: 0.6299 - val_accuracy: 0.7850
# Epoch 2/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5797 - accuracy: 0.7997 - val_loss: 0.5264 - val_accuracy: 0.8114
# Epoch 3/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5077 - accuracy: 0.8214 - val_loss: 0.4825 - val_accuracy: 0.8300
# Epoch 4/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4691 - accuracy: 0.8342 - val_loss: 0.4531 - val_accuracy: 0.8412
# Epoch 5/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4437 - accuracy: 0.8440 - val_loss: 0.4353 - val_accuracy: 0.8470
# Epoch 6/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4247 - accuracy: 0.8503 - val_loss: 0.4216 - val_accuracy: 0.8520
# Epoch 7/20
# 1719/1719 [==============================] - 4s 3ms/step - loss: 0.4097 - accuracy: 0.8559 - val_loss: 0.4099 - val_accuracy: 0.8552
# Epoch 8/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3973 - accuracy: 0.8599 - val_loss: 0.4025 - val_accuracy: 0.8596
# Epoch 9/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3867 - accuracy: 0.8640 - val_loss: 0.3935 - val_accuracy: 0.8622
# Epoch 10/20
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.3773 - accuracy: 0.8675 - val_loss: 0.3881 - val_accuracy: 0.8618
# Epoch 11/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3693 - accuracy: 0.8703 - val_loss: 0.3820 - val_accuracy: 0.8656
# Epoch 12/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3619 - accuracy: 0.8732 - val_loss: 0.3773 - val_accuracy: 0.8660
# Epoch 13/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3553 - accuracy: 0.8757 - val_loss: 0.3718 - val_accuracy: 0.8690
# Epoch 14/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3492 - accuracy: 0.8773 - val_loss: 0.3690 - val_accuracy: 0.8688
# Epoch 15/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3435 - accuracy: 0.8793 - val_loss: 0.3657 - val_accuracy: 0.8690
# Epoch 16/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3381 - accuracy: 0.8813 - val_loss: 0.3612 - val_accuracy: 0.8724
# Epoch 17/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3332 - accuracy: 0.8821 - val_loss: 0.3588 - val_accuracy: 0.8722
# Epoch 18/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3284 - accuracy: 0.8846 - val_loss: 0.3552 - val_accuracy: 0.8732
# Epoch 19/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3241 - accuracy: 0.8852 - val_loss: 0.3543 - val_accuracy: 0.8754
# Epoch 20/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3199 - accuracy: 0.8861 - val_loss: 0.3503 - val_accuracy: 0.8762
# Model Evaluation
# 313/313 [==============================] - 0s 2ms/step - loss: 0.3809 - accuracy: 0.8636

# %% [markdown]
# Note that the validation curve is smoother than in the previous test and it is also more simlar to the training curve.

# %% [markdown]
# ## Exercise 2.2: Overfiting
#
# A common problem that occurs when you train a deep neural network is overfittig. Overfitting occurs when you achieve a good fit of your model on the training data, while it does not generalize well on new, unseen data. In other words, the model learned patterns specific to the training data, which are irrelevant in other data.
# As we have seen in the previous exercise, our model does not overfit the training data. In this exercise, we try to modify the training parameters in order to have a model that overfits.
# Overfitting can have many causes and usually is a combination of some of them, for instance: too many parameters/ layers, too few training samples, wrong learning rate (usualy too high), etc..

# %%
#To complete: modify the previuos model in order to obtain  a new mdel that overfit the training data
#HINT: A model tends to overfit when too few training examples are available
X_train_small = X_train_full[:600]
y_train_small = y_train_full[:600]

#for i in range(5):
 # model.add(keras.layers.Dense(200, activation="relu"))


#To complete: Add layers
#HINT: A model tends to overfit  when the number of learnable parameters is very high compared to the number of training samples
#HINT: Is it possible to use different activation functions than ReLu
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
model.add(keras.layers.Dense(100, activation="relu"))
model.add(keras.layers.Dense(90, activation="relu"))
model.add(keras.layers.Dense(80, activation="relu"))
model.add(keras.layers.Dense(70, activation="relu"))
model.add(keras.layers.Dense(60, activation="relu"))
model.add(keras.layers.Dense(50, activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))


model.compile(loss="sparse_categorical_crossentropy",optimizer=keras.optimizers.SGD(lr=0.001),metrics=['accuracy']) #To complete:learning rate

#HINT: A model tends to overfit when the number of training epochs is high
history = model.fit(X_train_small, y_train_small, epochs=100,validation_data=(X_valid, y_valid))
print("Model Evaluation")
model.evaluate(X_test, y_test)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 0s 19ms/step - loss: 7.2144 - accuracy: 0.2600 - val_loss: 2.1989 - val_accuracy: 0.4112
# Epoch 2/100
# 19/19 [==============================] - 0s 14ms/step - loss: 1.7711 - accuracy: 0.4833 - val_loss: 1.7171 - val_accuracy: 0.5002
# Epoch 3/100
# 19/19 [==============================] - 0s 14ms/step - loss: 1.2915 - accuracy: 0.6050 - val_loss: 1.4629 - val_accuracy: 0.5676
# Epoch 4/100
# 19/19 [==============================] - 0s 14ms/step - loss: 1.0026 - accuracy: 0.6717 - val_loss: 1.2741 - val_accuracy: 0.6044
# Epoch 5/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.8630 - accuracy: 0.7317 - val_loss: 1.2879 - val_accuracy: 0.6202
# Epoch 6/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.7151 - accuracy: 0.7533 - val_loss: 1.1587 - val_accuracy: 0.6478
# Epoch 7/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.6481 - accuracy: 0.7950 - val_loss: 1.2097 - val_accuracy: 0.6434
# Epoch 8/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.5559 - accuracy: 0.8150 - val_loss: 1.1070 - val_accuracy: 0.6628
# Epoch 9/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.4643 - accuracy: 0.8550 - val_loss: 1.0856 - val_accuracy: 0.6744
# Epoch 10/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.4585 - accuracy: 0.8433 - val_loss: 1.0471 - val_accuracy: 0.6886
# Epoch 11/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.3556 - accuracy: 0.9050 - val_loss: 1.0701 - val_accuracy: 0.6778
# Epoch 12/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.3317 - accuracy: 0.8983 - val_loss: 1.0496 - val_accuracy: 0.6946
# Epoch 13/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.2942 - accuracy: 0.9183 - val_loss: 1.0904 - val_accuracy: 0.6850
# Epoch 14/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.2607 - accuracy: 0.9333 - val_loss: 1.0006 - val_accuracy: 0.7104
# Epoch 15/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.2286 - accuracy: 0.9367 - val_loss: 1.1322 - val_accuracy: 0.6850
# Epoch 16/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.2432 - accuracy: 0.9383 - val_loss: 0.9876 - val_accuracy: 0.7184
# Epoch 17/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1956 - accuracy: 0.9517 - val_loss: 1.0095 - val_accuracy: 0.7202
# Epoch 18/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1669 - accuracy: 0.9700 - val_loss: 0.9810 - val_accuracy: 0.7228
# Epoch 19/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1513 - accuracy: 0.9667 - val_loss: 0.9963 - val_accuracy: 0.7280
# Epoch 20/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1280 - accuracy: 0.9833 - val_loss: 1.0056 - val_accuracy: 0.7278
# Epoch 21/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1221 - accuracy: 0.9883 - val_loss: 1.0005 - val_accuracy: 0.7272
# Epoch 22/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1005 - accuracy: 0.9917 - val_loss: 1.0092 - val_accuracy: 0.7274
# Epoch 23/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0921 - accuracy: 0.9950 - val_loss: 1.0111 - val_accuracy: 0.7292
# Epoch 24/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0846 - accuracy: 0.9933 - val_loss: 1.0016 - val_accuracy: 0.7342
# Epoch 25/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0769 - accuracy: 0.9950 - val_loss: 1.0228 - val_accuracy: 0.7330
# Epoch 26/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0751 - accuracy: 0.9933 - val_loss: 1.0212 - val_accuracy: 0.7306
# Epoch 27/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0711 - accuracy: 0.9950 - val_loss: 1.0181 - val_accuracy: 0.7362
# Epoch 28/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0632 - accuracy: 1.0000 - val_loss: 1.0296 - val_accuracy: 0.7352
# Epoch 29/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0594 - accuracy: 1.0000 - val_loss: 1.0185 - val_accuracy: 0.7388
# Epoch 30/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0561 - accuracy: 1.0000 - val_loss: 1.0195 - val_accuracy: 0.7372
# Epoch 31/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0524 - accuracy: 1.0000 - val_loss: 1.0201 - val_accuracy: 0.7402
# Epoch 32/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0502 - accuracy: 1.0000 - val_loss: 1.0197 - val_accuracy: 0.7418
# Epoch 33/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0470 - accuracy: 1.0000 - val_loss: 1.0306 - val_accuracy: 0.7390
# Epoch 34/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0459 - accuracy: 1.0000 - val_loss: 1.0374 - val_accuracy: 0.7384
# Epoch 35/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0428 - accuracy: 1.0000 - val_loss: 1.0391 - val_accuracy: 0.7402
# Epoch 36/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0406 - accuracy: 1.0000 - val_loss: 1.0420 - val_accuracy: 0.7406
# Epoch 37/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0392 - accuracy: 1.0000 - val_loss: 1.0471 - val_accuracy: 0.7418
# Epoch 38/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0370 - accuracy: 1.0000 - val_loss: 1.0474 - val_accuracy: 0.7412
# Epoch 39/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0357 - accuracy: 1.0000 - val_loss: 1.0461 - val_accuracy: 0.7398
# Epoch 40/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0344 - accuracy: 1.0000 - val_loss: 1.0520 - val_accuracy: 0.7418
# Epoch 41/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0334 - accuracy: 1.0000 - val_loss: 1.0528 - val_accuracy: 0.7428
# Epoch 42/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0322 - accuracy: 1.0000 - val_loss: 1.0537 - val_accuracy: 0.7448
# Epoch 43/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0309 - accuracy: 1.0000 - val_loss: 1.0649 - val_accuracy: 0.7440
# Epoch 44/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 1.0610 - val_accuracy: 0.7426
# Epoch 45/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0284 - accuracy: 1.0000 - val_loss: 1.0703 - val_accuracy: 0.7452
# Epoch 46/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0277 - accuracy: 1.0000 - val_loss: 1.0690 - val_accuracy: 0.7408
# Epoch 47/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0266 - accuracy: 1.0000 - val_loss: 1.0667 - val_accuracy: 0.7446
# Epoch 48/100
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0260 - accuracy: 1.0000 - val_loss: 1.0725 - val_accuracy: 0.7418
# Epoch 49/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 1.0767 - val_accuracy: 0.7436
# Epoch 50/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 1.0774 - val_accuracy: 0.7454
# Epoch 51/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 1.0806 - val_accuracy: 0.7442
# Epoch 52/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0229 - accuracy: 1.0000 - val_loss: 1.0820 - val_accuracy: 0.7458
# Epoch 53/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 1.0832 - val_accuracy: 0.7438
# Epoch 54/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 1.0836 - val_accuracy: 0.7468
# Epoch 55/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 1.0921 - val_accuracy: 0.7454
# Epoch 56/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 1.0951 - val_accuracy: 0.7462
# Epoch 57/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 1.0895 - val_accuracy: 0.7464
# Epoch 58/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 1.0914 - val_accuracy: 0.7462
# Epoch 59/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 1.0953 - val_accuracy: 0.7456
# Epoch 60/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 1.0948 - val_accuracy: 0.7474
# Epoch 61/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 1.0976 - val_accuracy: 0.7474
# Epoch 62/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 1.1020 - val_accuracy: 0.7464
# Epoch 63/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 1.1030 - val_accuracy: 0.7470
# Epoch 64/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 1.1024 - val_accuracy: 0.7484
# Epoch 65/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 1.1101 - val_accuracy: 0.7472
# Epoch 66/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 1.1041 - val_accuracy: 0.7488
# Epoch 67/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 1.1061 - val_accuracy: 0.7486
# Epoch 68/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 1.1105 - val_accuracy: 0.7480
# Epoch 69/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 1.1116 - val_accuracy: 0.7468
# Epoch 70/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 1.1148 - val_accuracy: 0.7470
# Epoch 71/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 1.1117 - val_accuracy: 0.7490
# Epoch 72/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 1.1218 - val_accuracy: 0.7472
# Epoch 73/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 1.1197 - val_accuracy: 0.7488
# Epoch 74/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 1.1199 - val_accuracy: 0.7480
# Epoch 75/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 1.1228 - val_accuracy: 0.7498
# Epoch 76/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 1.1217 - val_accuracy: 0.7500
# Epoch 77/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 1.1267 - val_accuracy: 0.7498
# Epoch 78/100
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 1.1259 - val_accuracy: 0.7488
# Epoch 79/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 1.1284 - val_accuracy: 0.7508
# Epoch 80/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 1.1284 - val_accuracy: 0.7526
# Epoch 81/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 1.1272 - val_accuracy: 0.7510
# Epoch 82/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 1.1316 - val_accuracy: 0.7526
# Epoch 83/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 1.1354 - val_accuracy: 0.7514
# Epoch 84/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 1.1362 - val_accuracy: 0.7502
# Epoch 85/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 1.1352 - val_accuracy: 0.7518
# Epoch 86/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 1.1374 - val_accuracy: 0.7514
# Epoch 87/100
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 1.1402 - val_accuracy: 0.7512
# Epoch 88/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 1.1426 - val_accuracy: 0.7510
# Epoch 89/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 1.1477 - val_accuracy: 0.7500
# Epoch 90/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 1.1442 - val_accuracy: 0.7518
# Epoch 91/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.1475 - val_accuracy: 0.7526
# Epoch 92/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.1482 - val_accuracy: 0.7514
# Epoch 93/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 1.1488 - val_accuracy: 0.7524
# Epoch 94/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 1.1518 - val_accuracy: 0.7524
# Epoch 95/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 1.1529 - val_accuracy: 0.7516
# Epoch 96/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 1.1531 - val_accuracy: 0.7532
# Epoch 97/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 1.1542 - val_accuracy: 0.7516
# Epoch 98/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 1.1562 - val_accuracy: 0.7526
# Epoch 99/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 1.1570 - val_accuracy: 0.7532
# Epoch 100/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 1.1585 - val_accuracy: 0.7538
# Model Evaluation
# 313/313 [==============================] - 0s 1ms/step - loss: 1.5138 - accuracy: 0.6869
# [1.5138468742370605, 0.6869000196456909]

# %% [markdown]
# Define the plot_learning_loss function and plot the loss and val_loss trends

# %%
def plot_learning_loss(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.show()
plot_learning_loss(history)
#######################################
#I added this function to see the function's behaviour between [0,1] in particular the accuracy metric
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 1)
    plt.show()
plot_learning_curves(history)

# %% [markdown]
# ### L1-norm
#
# One possible way to solve the overitting issue is by using regularization methods. The two most common regularization methods in Deep Learning are the L1-norm regularization and the L2-norm regularization. Both These techniques are based on limiting the capacity of models, by adding a parameter norm penalty to the objective function $\mathcal{J}$:
# $$
# \hat{\mathcal{J}}(\theta,\mathbf{X},\mathbf{y}) = \mathcal{J}(\theta,\mathbf{X},\mathbf{y}) + \alpha \Omega(\theta)
# $$
# where $\alpha$ is a hyperparameter that weighs the relative contribution of the norm penalty $\Omega$.
# Lets start by considering the L1-norm regularization where the regularization term is defined as:
# $$
#  \Omega(\theta)=||\mathbf{W}||_1=\sum_i |\mathbf{w}|
# $$
# Let's find the values for the $\alpha$ parameters that allow removing remove the overfitting effect.

# %%
#####################################################################################################################
#Why we use the regularization?

#Let's consider Occam's razor principle: give two explanations for something, the simplest one tends to be also the most correct. 
#This idea applies also to the models learned from neural networks: training data and a network architecture, there are many value sets of weights (and therefore models) 
#able to "explain" the data. The simpler models tend to suffer less overfits than the complex ones.
#A simple model is such that the distribution of parameter values has less entropy. 
#Therefore, a common way to mitigate overfitting is to impose constraints on the complexity of the network by forcing its weights to assume only small values 
#that make the distribution of the values of the weights more regular. 
#The regularization of weights is carried out by adding to the objective function of the network a cost associated with the presence of large weights.
#########################################################################################################################

#Regularization L1: the added cost is proportional to the absolute value of the weight coefficients.
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
model.add(keras.layers.Dense(100, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(1e-4))) 
model.add(keras.layers.Dense(90, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(1e-4))) 
model.add(keras.layers.Dense(80, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(1e-4))) 
model.add(keras.layers.Dense(70, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(1e-4))) 
model.add(keras.layers.Dense(60, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(1e-4))) 
model.add(keras.layers.Dense(50, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(1e-4))) 
#model.add(keras.layers.Dense(300, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(1e-4))) 
#for i in range(10):
 # model.add(keras.layers.Dense(100, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(1e-4))) 

model.add(keras.layers.Dense(10, activation="softmax")) 


model.compile(loss="sparse_categorical_crossentropy", optimizer=keras.optimizers.SGD(lr=0.0001),metrics=['accuracy']) 


history = model.fit(X_train_small, y_train_small, epochs=50, #To complete: number of epochs
                    validation_data=(X_valid, y_valid))
print("Model Evaluation")
model.evaluate(X_test, y_test)
plot_learning_loss(history)
#I recall this function plot to see the accuracy
plot_learning_curves(history)
# Out:
# Epoch 1/50
# 19/19 [==============================] - 0s 24ms/step - loss: 15.3825 - accuracy: 0.1217 - val_loss: 6.8260 - val_accuracy: 0.1886
# Epoch 2/50
# 19/19 [==============================] - 0s 15ms/step - loss: 5.7058 - accuracy: 0.2583 - val_loss: 5.1538 - val_accuracy: 0.2522
# Epoch 3/50
# 19/19 [==============================] - 0s 15ms/step - loss: 4.3544 - accuracy: 0.3467 - val_loss: 4.3257 - val_accuracy: 0.3206
# Epoch 4/50
# 19/19 [==============================] - 0s 15ms/step - loss: 3.6335 - accuracy: 0.3800 - val_loss: 3.9094 - val_accuracy: 0.3354
# Epoch 5/50
# 19/19 [==============================] - 0s 15ms/step - loss: 3.1677 - accuracy: 0.4117 - val_loss: 3.5734 - val_accuracy: 0.3740
# Epoch 6/50
# 19/19 [==============================] - 0s 15ms/step - loss: 2.8247 - accuracy: 0.4567 - val_loss: 3.3415 - val_accuracy: 0.3982
# Epoch 7/50
# 19/19 [==============================] - 0s 15ms/step - loss: 2.5505 - accuracy: 0.4883 - val_loss: 3.2191 - val_accuracy: 0.4138
# Epoch 8/50
# 19/19 [==============================] - 0s 15ms/step - loss: 2.4127 - accuracy: 0.5150 - val_loss: 3.0869 - val_accuracy: 0.4374
# Epoch 9/50
# 19/19 [==============================] - 0s 15ms/step - loss: 2.2322 - accuracy: 0.5517 - val_loss: 2.9706 - val_accuracy: 0.4506
# Epoch 10/50
# 19/19 [==============================] - 0s 14ms/step - loss: 2.1343 - accuracy: 0.5683 - val_loss: 2.8693 - val_accuracy: 0.4742
# Epoch 11/50
# 19/19 [==============================] - 0s 15ms/step - loss: 2.0063 - accuracy: 0.6000 - val_loss: 2.8059 - val_accuracy: 0.4806
# Epoch 12/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.9221 - accuracy: 0.6300 - val_loss: 2.7462 - val_accuracy: 0.4944
# Epoch 13/50
# 19/19 [==============================] - 0s 16ms/step - loss: 1.8806 - accuracy: 0.6383 - val_loss: 2.7102 - val_accuracy: 0.5032
# Epoch 14/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.7849 - accuracy: 0.6467 - val_loss: 2.6481 - val_accuracy: 0.5068
# Epoch 15/50
# 19/19 [==============================] - 0s 14ms/step - loss: 1.7358 - accuracy: 0.6733 - val_loss: 2.6454 - val_accuracy: 0.5106
# Epoch 16/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.6750 - accuracy: 0.6967 - val_loss: 2.6143 - val_accuracy: 0.5192
# Epoch 17/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.6294 - accuracy: 0.6900 - val_loss: 2.5511 - val_accuracy: 0.5216
# Epoch 18/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.5892 - accuracy: 0.7067 - val_loss: 2.5333 - val_accuracy: 0.5320
# Epoch 19/50
# 19/19 [==============================] - 0s 16ms/step - loss: 1.5396 - accuracy: 0.7200 - val_loss: 2.5263 - val_accuracy: 0.5418
# Epoch 20/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.5235 - accuracy: 0.7300 - val_loss: 2.4992 - val_accuracy: 0.5344
# Epoch 21/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.4842 - accuracy: 0.7300 - val_loss: 2.4731 - val_accuracy: 0.5492
# Epoch 22/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.4510 - accuracy: 0.7383 - val_loss: 2.4446 - val_accuracy: 0.5520
# Epoch 23/50
# 19/19 [==============================] - 0s 16ms/step - loss: 1.4113 - accuracy: 0.7633 - val_loss: 2.4263 - val_accuracy: 0.5522
# Epoch 24/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.3904 - accuracy: 0.7650 - val_loss: 2.4133 - val_accuracy: 0.5590
# Epoch 25/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.3635 - accuracy: 0.7800 - val_loss: 2.4066 - val_accuracy: 0.5622
# Epoch 26/50
# 19/19 [==============================] - 0s 16ms/step - loss: 1.3353 - accuracy: 0.7867 - val_loss: 2.3979 - val_accuracy: 0.5606
# Epoch 27/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.3245 - accuracy: 0.7833 - val_loss: 2.4454 - val_accuracy: 0.5560
# Epoch 28/50
# 19/19 [==============================] - 0s 16ms/step - loss: 1.2987 - accuracy: 0.7917 - val_loss: 2.3659 - val_accuracy: 0.5692
# Epoch 29/50
# 19/19 [==============================] - 0s 17ms/step - loss: 1.2689 - accuracy: 0.8100 - val_loss: 2.3439 - val_accuracy: 0.5742
# Epoch 30/50
# 19/19 [==============================] - 0s 16ms/step - loss: 1.2531 - accuracy: 0.8183 - val_loss: 2.3489 - val_accuracy: 0.5766
# Epoch 31/50
# 19/19 [==============================] - 0s 16ms/step - loss: 1.2386 - accuracy: 0.8100 - val_loss: 2.3341 - val_accuracy: 0.5768
# Epoch 32/50
# 19/19 [==============================] - 0s 17ms/step - loss: 1.2131 - accuracy: 0.8167 - val_loss: 2.3520 - val_accuracy: 0.5746
# Epoch 33/50
# 19/19 [==============================] - 0s 16ms/step - loss: 1.2035 - accuracy: 0.8233 - val_loss: 2.3075 - val_accuracy: 0.5834
# Epoch 34/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.1808 - accuracy: 0.8183 - val_loss: 2.3030 - val_accuracy: 0.5864
# Epoch 35/50
# 19/19 [==============================] - 0s 16ms/step - loss: 1.1656 - accuracy: 0.8350 - val_loss: 2.2977 - val_accuracy: 0.5910
# Epoch 36/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.1468 - accuracy: 0.8417 - val_loss: 2.2958 - val_accuracy: 0.5918
# Epoch 37/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.1364 - accuracy: 0.8417 - val_loss: 2.2834 - val_accuracy: 0.5896
# Epoch 38/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.1223 - accuracy: 0.8483 - val_loss: 2.2697 - val_accuracy: 0.5962
# Epoch 39/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.1011 - accuracy: 0.8600 - val_loss: 2.2568 - val_accuracy: 0.5978
# Epoch 40/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.0980 - accuracy: 0.8550 - val_loss: 2.2757 - val_accuracy: 0.5966
# Epoch 41/50
# 19/19 [==============================] - 0s 14ms/step - loss: 1.0867 - accuracy: 0.8667 - val_loss: 2.2477 - val_accuracy: 0.6028
# Epoch 42/50
# 19/19 [==============================] - 0s 17ms/step - loss: 1.0828 - accuracy: 0.8533 - val_loss: 2.2500 - val_accuracy: 0.6048
# Epoch 43/50
# 19/19 [==============================] - 0s 16ms/step - loss: 1.0592 - accuracy: 0.8667 - val_loss: 2.2559 - val_accuracy: 0.6022
# Epoch 44/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.0473 - accuracy: 0.8733 - val_loss: 2.2376 - val_accuracy: 0.6058
# Epoch 45/50
# 19/19 [==============================] - 0s 14ms/step - loss: 1.0458 - accuracy: 0.8800 - val_loss: 2.2238 - val_accuracy: 0.6064
# Epoch 46/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.0290 - accuracy: 0.8717 - val_loss: 2.2320 - val_accuracy: 0.6092
# Epoch 47/50
# 19/19 [==============================] - 0s 16ms/step - loss: 1.0235 - accuracy: 0.8833 - val_loss: 2.2161 - val_accuracy: 0.6120
# Epoch 48/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.0133 - accuracy: 0.8767 - val_loss: 2.2152 - val_accuracy: 0.6106
# Epoch 49/50
# 19/19 [==============================] - 0s 15ms/step - loss: 1.0049 - accuracy: 0.8767 - val_loss: 2.2106 - val_accuracy: 0.6108
# Epoch 50/50
# 19/19 [==============================] - 0s 15ms/step - loss: 0.9947 - accuracy: 0.8900 - val_loss: 2.2091 - val_accuracy: 0.6158
# Model Evaluation
# 313/313 [==============================] - 0s 1ms/step - loss: 2.4258 - accuracy: 0.5736

# %% [markdown]
# ### L2-norm
#
# L2-norm regularization is also known as weight decay. This strategy drives the weights closer to the origin by adding the regularization term omega which is defined as:
# $$
#  \Omega(\theta)=\frac{1}{2}||\mathbf{W}||_2^2
# $$
#
# Let's find the values for the $\alpha$ parameters that allow removing remove the overfitting effect with L2-norm.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))

#Regularisation L2: the added cost is proportional to the square of the value of the weight coefficients. 

#model.add(keras.layers.Dense(300, activation="relu",kernel_regularizer=tf.keras.regularizers.l2(1e-4))) 
#for i in range(10):
  #model.add(keras.layers.Dense(100, activation="relu",kernel_regularizer=tf.keras.regularizers.l2(1e-4))) 


model.add(keras.layers.Dense(100, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(5e-3))) 
model.add(keras.layers.Dense(90, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(5e-3))) 
model.add(keras.layers.Dense(80, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(5e-3))) 
model.add(keras.layers.Dense(70, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(5e-3))) 
model.add(keras.layers.Dense(60, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(5e-3))) 
model.add(keras.layers.Dense(50, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(5e-3))) 
model.add(keras.layers.Dense(10, activation="softmax")) 


model.compile(loss="sparse_categorical_crossentropy",optimizer=keras.optimizers.SGD(lr=0.0001),metrics=['accuracy']) 

history = model.fit(X_train_small, y_train_small, epochs=50, validation_data=(X_valid, y_valid))

print("Model Evaluation")
model.evaluate(X_test, y_test)
plot_learning_loss(history)
#I recall this function plot to see the accuracy
plot_learning_curves(history)
# Out:
# Epoch 1/50
# 19/19 [==============================] - 0s 22ms/step - loss: 42.4000 - accuracy: 0.1833 - val_loss: 36.2691 - val_accuracy: 0.2336
# Epoch 2/50
# 19/19 [==============================] - 0s 15ms/step - loss: 35.0842 - accuracy: 0.2817 - val_loss: 34.3818 - val_accuracy: 0.2984
# Epoch 3/50
# 19/19 [==============================] - 0s 16ms/step - loss: 33.9117 - accuracy: 0.3417 - val_loss: 33.7478 - val_accuracy: 0.3352
# Epoch 4/50
# 19/19 [==============================] - 0s 15ms/step - loss: 33.3139 - accuracy: 0.3983 - val_loss: 33.3890 - val_accuracy: 0.3614
# Epoch 5/50
# 19/19 [==============================] - 0s 15ms/step - loss: 32.9108 - accuracy: 0.4267 - val_loss: 33.0983 - val_accuracy: 0.3786
# Epoch 6/50
# 19/19 [==============================] - 0s 15ms/step - loss: 32.6262 - accuracy: 0.4550 - val_loss: 32.8741 - val_accuracy: 0.3980
# Epoch 7/50
# 19/19 [==============================] - 0s 16ms/step - loss: 32.3712 - accuracy: 0.4967 - val_loss: 32.7233 - val_accuracy: 0.4108
# Epoch 8/50
# 19/19 [==============================] - 0s 16ms/step - loss: 32.1675 - accuracy: 0.5300 - val_loss: 32.5614 - val_accuracy: 0.4358
# Epoch 9/50
# 19/19 [==============================] - 0s 15ms/step - loss: 31.9954 - accuracy: 0.5533 - val_loss: 32.4636 - val_accuracy: 0.4524
# Epoch 10/50
# 19/19 [==============================] - 0s 15ms/step - loss: 31.8672 - accuracy: 0.5567 - val_loss: 32.3251 - val_accuracy: 0.4686
# Epoch 11/50
# 19/19 [==============================] - 0s 14ms/step - loss: 31.7592 - accuracy: 0.5950 - val_loss: 32.2517 - val_accuracy: 0.4812
# Epoch 12/50
# 19/19 [==============================] - 0s 15ms/step - loss: 31.6404 - accuracy: 0.6033 - val_loss: 32.1764 - val_accuracy: 0.4896
# Epoch 13/50
# 19/19 [==============================] - 0s 15ms/step - loss: 31.5682 - accuracy: 0.6300 - val_loss: 32.1177 - val_accuracy: 0.4944
# Epoch 14/50
# 19/19 [==============================] - 0s 15ms/step - loss: 31.4856 - accuracy: 0.6233 - val_loss: 32.0696 - val_accuracy: 0.5014
# Epoch 15/50
# 19/19 [==============================] - 0s 14ms/step - loss: 31.4125 - accuracy: 0.6517 - val_loss: 32.0164 - val_accuracy: 0.5146
# Epoch 16/50
# 19/19 [==============================] - 0s 15ms/step - loss: 31.3545 - accuracy: 0.6617 - val_loss: 31.9724 - val_accuracy: 0.5206
# Epoch 17/50
# 19/19 [==============================] - 0s 15ms/step - loss: 31.2820 - accuracy: 0.6600 - val_loss: 31.9324 - val_accuracy: 0.5226
# Epoch 18/50
# 19/19 [==============================] - 0s 15ms/step - loss: 31.2457 - accuracy: 0.6850 - val_loss: 31.9151 - val_accuracy: 0.5274
# Epoch 19/50
# 19/19 [==============================] - 0s 15ms/step - loss: 31.1963 - accuracy: 0.7083 - val_loss: 31.8621 - val_accuracy: 0.5352
# Epoch 20/50
# 19/19 [==============================] - 0s 15ms/step - loss: 31.1530 - accuracy: 0.7033 - val_loss: 31.8411 - val_accuracy: 0.5390
# Epoch 21/50
# 19/19 [==============================] - 0s 15ms/step - loss: 31.1098 - accuracy: 0.7250 - val_loss: 31.8195 - val_accuracy: 0.5384
# Epoch 22/50
# 19/19 [==============================] - 0s 15ms/step - loss: 31.0796 - accuracy: 0.7183 - val_loss: 31.7819 - val_accuracy: 0.5530
# Epoch 23/50
# 19/19 [==============================] - 0s 17ms/step - loss: 31.0454 - accuracy: 0.7400 - val_loss: 31.7530 - val_accuracy: 0.5512
# Epoch 24/50
# 19/19 [==============================] - 0s 15ms/step - loss: 31.0071 - accuracy: 0.7367 - val_loss: 31.7371 - val_accuracy: 0.5594
# Epoch 25/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.9714 - accuracy: 0.7467 - val_loss: 31.7138 - val_accuracy: 0.5612
# Epoch 26/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.9389 - accuracy: 0.7400 - val_loss: 31.6915 - val_accuracy: 0.5698
# Epoch 27/50
# 19/19 [==============================] - 0s 17ms/step - loss: 30.9216 - accuracy: 0.7550 - val_loss: 31.6842 - val_accuracy: 0.5676
# Epoch 28/50
# 19/19 [==============================] - 0s 16ms/step - loss: 30.8826 - accuracy: 0.7567 - val_loss: 31.6586 - val_accuracy: 0.5726
# Epoch 29/50
# 19/19 [==============================] - 0s 16ms/step - loss: 30.8575 - accuracy: 0.7783 - val_loss: 31.6437 - val_accuracy: 0.5746
# Epoch 30/50
# 19/19 [==============================] - 0s 16ms/step - loss: 30.8359 - accuracy: 0.7733 - val_loss: 31.6172 - val_accuracy: 0.5784
# Epoch 31/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.8069 - accuracy: 0.7750 - val_loss: 31.5987 - val_accuracy: 0.5828
# Epoch 32/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.7864 - accuracy: 0.7867 - val_loss: 31.5879 - val_accuracy: 0.5890
# Epoch 33/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.7648 - accuracy: 0.7833 - val_loss: 31.5698 - val_accuracy: 0.5868
# Epoch 34/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.7458 - accuracy: 0.7867 - val_loss: 31.5503 - val_accuracy: 0.5912
# Epoch 35/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.7232 - accuracy: 0.7950 - val_loss: 31.5325 - val_accuracy: 0.5878
# Epoch 36/50
# 19/19 [==============================] - 0s 16ms/step - loss: 30.7006 - accuracy: 0.7983 - val_loss: 31.5191 - val_accuracy: 0.5906
# Epoch 37/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.6863 - accuracy: 0.8050 - val_loss: 31.5029 - val_accuracy: 0.5968
# Epoch 38/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.6604 - accuracy: 0.8133 - val_loss: 31.4882 - val_accuracy: 0.6004
# Epoch 39/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.6407 - accuracy: 0.8100 - val_loss: 31.4778 - val_accuracy: 0.6034
# Epoch 40/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.6246 - accuracy: 0.8250 - val_loss: 31.4710 - val_accuracy: 0.6068
# Epoch 41/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.6131 - accuracy: 0.8317 - val_loss: 31.4537 - val_accuracy: 0.6054
# Epoch 42/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.5856 - accuracy: 0.8400 - val_loss: 31.4478 - val_accuracy: 0.6082
# Epoch 43/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.5719 - accuracy: 0.8483 - val_loss: 31.4297 - val_accuracy: 0.6106
# Epoch 44/50
# 19/19 [==============================] - 0s 16ms/step - loss: 30.5551 - accuracy: 0.8450 - val_loss: 31.4212 - val_accuracy: 0.6126
# Epoch 45/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.5424 - accuracy: 0.8533 - val_loss: 31.4107 - val_accuracy: 0.6134
# Epoch 46/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.5333 - accuracy: 0.8550 - val_loss: 31.4008 - val_accuracy: 0.6156
# Epoch 47/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.5156 - accuracy: 0.8483 - val_loss: 31.3862 - val_accuracy: 0.6200
# Epoch 48/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.4949 - accuracy: 0.8650 - val_loss: 31.3844 - val_accuracy: 0.6168
# Epoch 49/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.4848 - accuracy: 0.8617 - val_loss: 31.3792 - val_accuracy: 0.6174
# Epoch 50/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.4661 - accuracy: 0.8700 - val_loss: 31.3584 - val_accuracy: 0.6236
# Model Evaluation
# 313/313 [==============================] - 0s 2ms/step - loss: 31.5970 - accuracy: 0.5637

# %% [markdown]
# ### Early stopping
#
# Early Stopping is a form of regularization used to avoid overfitting. It is designed to monitor the generalization error of one model and stop training when generalization error begins to degrade. In order to evaluate the generalization error, early stopping requires that a validation dataset is evaluated during training. Then, when the validation error does not improve for a specific number of epochs (patience hyper-parameter), it stops the training phase.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
model.add(keras.layers.Dense(300, activation="relu"))
model.add(keras.layers.Dense(500,activation="relu"))
model.add(keras.layers.Dense(600,activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))


model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=0.001)) #To complete: learning rate

#Let's define a log dir in order to save the checkpoint file
logdir = os.path.join(os.curdir, "my_logs", "run_{}".format(time.time()))

#In Keras the Eraly stopping is manage by using the callbacks argument.
callbacks = [
    keras.callbacks.TensorBoard(logdir),
    keras.callbacks.EarlyStopping(patience=30), #To complete: play with patience and find the value that prevents the model from overfitting
    #Saving the checkpoints file allows to load the "best" model when the Early 
    #stopping detect that the generalization error degrade (after 'patience' epochs)
    keras.callbacks.ModelCheckpoint("my_mnist_model.h5", save_best_only=True),
]

history = model.fit(X_train_small, y_train_small, epochs=100, #To complete: number of epochs
                    validation_data=(X_valid_scaled, y_valid),
                    callbacks=callbacks)

print("Model Evaluation")
#The early stopping stopped training after few epochs without progress, so your
#model may already have started to overfit the training set. Since the 
#ModelCheckpoint callback only saved the best models (on the validation set) the
#last saved model is the best on the validation set.
model = keras.models.load_model("my_mnist_model.h5")
model.evaluate(X_test, y_test)
plot_learning_loss(history)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 1s 28ms/step - loss: 41.5919 - val_loss: 2.4117
# Epoch 2/100
# 25/25 [==============================] - 1s 24ms/step - loss: 1.4498 - val_loss: 2.3318
# Epoch 3/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.8070 - val_loss: 2.3154
# Epoch 4/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.5343 - val_loss: 2.3170
# Epoch 5/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.4442 - val_loss: 2.3042
# Epoch 6/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.3436 - val_loss: 2.3001
# Epoch 7/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.2187 - val_loss: 2.3008
# Epoch 8/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.1929 - val_loss: 2.3019
# Epoch 9/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.1304 - val_loss: 2.3027
# Epoch 10/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.1132 - val_loss: 2.3023
# Epoch 11/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.1041 - val_loss: 2.3009
# Epoch 12/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0990 - val_loss: 2.2996
# Epoch 13/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.0752 - val_loss: 2.3028
# Epoch 14/100
# 25/25 [==============================] - 1s 28ms/step - loss: 0.0602 - val_loss: 2.3004
# Epoch 15/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.0468 - val_loss: 2.3001
# Epoch 16/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.0407 - val_loss: 2.2998
# Epoch 17/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0338 - val_loss: 2.3004
# Epoch 18/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0301 - val_loss: 2.2996
# Epoch 19/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.0263 - val_loss: 2.2996
# Epoch 20/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0236 - val_loss: 2.2992
# Epoch 21/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0217 - val_loss: 2.2987
# Epoch 22/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0192 - val_loss: 2.2985
# Epoch 23/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.0174 - val_loss: 2.2988
# Epoch 24/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0161 - val_loss: 2.2980
# Epoch 25/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0147 - val_loss: 2.2978
# Epoch 26/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.0139 - val_loss: 2.2978
# Epoch 27/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.0127 - val_loss: 2.2978
# Epoch 28/100
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0126 - val_loss: 2.2975
# Epoch 29/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0113 - val_loss: 2.2972
# Epoch 30/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0109 - val_loss: 2.2973
# Epoch 31/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0103 - val_loss: 2.2971
# Epoch 32/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0097 - val_loss: 2.2969
# Epoch 33/100
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0091 - val_loss: 2.2965
# Epoch 34/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.0091 - val_loss: 2.2966
# Epoch 35/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.0086 - val_loss: 2.2964
# Epoch 36/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0083 - val_loss: 2.2964
# Epoch 37/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0080 - val_loss: 2.2962
# Epoch 38/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0076 - val_loss: 2.2963
# Epoch 39/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0074 - val_loss: 2.2960
# Epoch 40/100
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0072 - val_loss: 2.2959
# Epoch 41/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0068 - val_loss: 2.2958
# Epoch 42/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0066 - val_loss: 2.2956
# Epoch 43/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0064 - val_loss: 2.2956
# Epoch 44/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0062 - val_loss: 2.2955
# Epoch 45/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0060 - val_loss: 2.2955
# Epoch 46/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0059 - val_loss: 2.2954
# Epoch 47/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.0057 - val_loss: 2.2953
# Epoch 48/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0056 - val_loss: 2.2950
# Epoch 49/100
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0054 - val_loss: 2.2950
# Epoch 50/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0053 - val_loss: 2.2949
# Epoch 51/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0052 - val_loss: 2.2948
# Epoch 52/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0050 - val_loss: 2.2947
# Epoch 53/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0049 - val_loss: 2.2946
# Epoch 54/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0048 - val_loss: 2.2945
# Epoch 55/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0047 - val_loss: 2.2945
# Epoch 56/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0046 - val_loss: 2.2944
# Epoch 57/100
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0045 - val_loss: 2.2943
# Epoch 58/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0044 - val_loss: 2.2942
# Epoch 59/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0043 - val_loss: 2.2942
# Epoch 60/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0042 - val_loss: 2.2940
# Epoch 61/100
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0041 - val_loss: 2.2940
# Epoch 62/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0040 - val_loss: 2.2939
# Epoch 63/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.0039 - val_loss: 2.2939
# Epoch 64/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0039 - val_loss: 2.2937
# Epoch 65/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0038 - val_loss: 2.2936
# Epoch 66/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0037 - val_loss: 2.2936
# Epoch 67/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0037 - val_loss: 2.2936
# Epoch 68/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0036 - val_loss: 2.2935
# Epoch 69/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0036 - val_loss: 2.2934
# Epoch 70/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.0035 - val_loss: 2.2933
# Epoch 71/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0034 - val_loss: 2.2933
# Epoch 72/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0034 - val_loss: 2.2932
# Epoch 73/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0033 - val_loss: 2.2932
# Epoch 74/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0032 - val_loss: 2.2931
# Epoch 75/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0032 - val_loss: 2.2930
# Epoch 76/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0032 - val_loss: 2.2930
# Epoch 77/100
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0031 - val_loss: 2.2929
# Epoch 78/100
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0031 - val_loss: 2.2928
# Epoch 79/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0030 - val_loss: 2.2928
# Epoch 80/100
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0030 - val_loss: 2.2927
# Epoch 81/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0029 - val_loss: 2.2927
# Epoch 82/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0029 - val_loss: 2.2926
# Epoch 83/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0028 - val_loss: 2.2925
# Epoch 84/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0028 - val_loss: 2.2925
# Epoch 85/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0028 - val_loss: 2.2924
# Epoch 86/100
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0027 - val_loss: 2.2924
# Epoch 87/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0027 - val_loss: 2.2923
# Epoch 88/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0027 - val_loss: 2.2923
# Epoch 89/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0026 - val_loss: 2.2922
# Epoch 90/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0026 - val_loss: 2.2921
# Epoch 91/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0026 - val_loss: 2.2921
# Epoch 92/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0025 - val_loss: 2.2920
# Epoch 93/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0025 - val_loss: 2.2920
# Epoch 94/100
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0025 - val_loss: 2.2919
# Epoch 95/100
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0024 - val_loss: 2.2919
# Epoch 96/100
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0024 - val_loss: 2.2919
# Epoch 97/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0024 - val_loss: 2.2918
# Epoch 98/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0024 - val_loss: 2.2917
# Epoch 99/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0023 - val_loss: 2.2917
# Epoch 100/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0023 - val_loss: 2.2917
# Model Evaluation
# 313/313 [==============================] - 1s 3ms/step - loss: 1.7809

# %% [markdown]
# ## Exercise 2.3: Model Selection
#
# Hyperparameters are the parameters of the learning method itself which we have to specify a priori, i.e., before model fitting. In contrast, model parameters are parameters which arise as a result of the fit. The aim of the model selection is selecting the best hyperparameters for our deep network. Finding the right hyperparameters for a model can be crucial for the model performance on given data. For istance lets consider our model trained by using different values for the learnign rate:

# %%
learning_rates = [1e-4, 1e-2, 1e-1]

# %%
histories = []
for learning_rate in learning_rates:
    model = keras.models.Sequential([
                                    keras.layers.Flatten(input_shape=[28, 28]),
                                    keras.layers.Dense(300, activation="relu"),
                                    keras.layers.Dense(10, activation="softmax")])

    model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=learning_rate),
              metrics=["accuracy"])
              
    callbacks = [keras.callbacks.EarlyStopping(patience=2)]

    history = model.fit(X_train_scaled, y_train,
                        validation_data=(X_valid_scaled, y_valid), epochs=10,
                        callbacks=callbacks)
    histories.append(history)
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 6s 3ms/step - loss: 1.8388 - accuracy: 0.3850 - val_loss: 1.2607 - val_accuracy: 0.6012
# Epoch 2/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 1.0994 - accuracy: 0.6494 - val_loss: 0.9740 - val_accuracy: 0.6884
# Epoch 3/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.9189 - accuracy: 0.7008 - val_loss: 0.8535 - val_accuracy: 0.7240
# Epoch 4/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.8285 - accuracy: 0.7273 - val_loss: 0.7830 - val_accuracy: 0.7458
# Epoch 5/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.7713 - accuracy: 0.7428 - val_loss: 0.7355 - val_accuracy: 0.7570
# Epoch 6/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.7305 - accuracy: 0.7538 - val_loss: 0.7004 - val_accuracy: 0.7648
# Epoch 7/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.6993 - accuracy: 0.7633 - val_loss: 0.6728 - val_accuracy: 0.7718
# Epoch 8/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.6743 - accuracy: 0.7700 - val_loss: 0.6503 - val_accuracy: 0.7810
# Epoch 9/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.6534 - accuracy: 0.7762 - val_loss: 0.6316 - val_accuracy: 0.7868
# Epoch 10/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.6357 - accuracy: 0.7816 - val_loss: 0.6154 - val_accuracy: 0.7920
# Epoch 1/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5132 - accuracy: 0.8214 - val_loss: 0.4002 - val_accuracy: 0.8630
# Epoch 2/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3774 - accuracy: 0.8669 - val_loss: 0.3616 - val_accuracy: 0.8768
# Epoch 3/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3411 - accuracy: 0.8795 - val_loss: 0.3603 - val_accuracy: 0.8730
# Epoch 4/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3173 - accuracy: 0.8870 - val_loss: 0.3343 - val_accuracy: 0.8842
# Epoch 5/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3000 - accuracy: 0.8930 - val_loss: 0.3291 - val_accuracy: 0.8824
# Epoch 6/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2833 - accuracy: 0.8992 - val_loss: 0.3280 - val_accuracy: 0.8820
# Epoch 7/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2705 - accuracy: 0.9038 - val_loss: 0.3211 - val_accuracy: 0.8860
# Epoch 8/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2589 - accuracy: 0.9085 - val_loss: 0.3279 - val_accuracy: 0.8822
# Epoch 9/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2479 - accuracy: 0.9117 - val_loss: 0.3143 - val_accuracy: 0.8880
# Epoch 10/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2378 - accuracy: 0.9154 - val_loss: 0.3118 - val_accuracy: 0.8904
# Epoch 1/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4773 - accuracy: 0.8334 - val_loss: 0.4142 - val_accuracy: 0.8550
# Epoch 2/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3495 - accuracy: 0.8735 - val_loss: 0.3645 - val_accuracy: 0.8768
# Epoch 3/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3049 - accuracy: 0.8897 - val_loss: 0.4443 - val_accuracy: 0.8496
# Epoch 4/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2766 - accuracy: 0.8991 - val_loss: 0.3562 - val_accuracy: 0.8810
# Epoch 5/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2548 - accuracy: 0.9067 - val_loss: 0.3536 - val_accuracy: 0.8904
# Epoch 6/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2351 - accuracy: 0.9149 - val_loss: 0.3679 - val_accuracy: 0.8884
# Epoch 7/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2210 - accuracy: 0.9201 - val_loss: 0.4240 - val_accuracy: 0.8740

# %% [markdown]
# Let's plot the results

# %%
for learning_rate, history in zip(learning_rates, histories):
    print("Learning rate:", learning_rate)
    plot_learning_curves(history)
# Out:
# Learning rate: 0.0001
# Learning rate: 0.01
# Learning rate: 0.1

# %% [markdown]
# Note that the learning rate influence significantly the training phase. That behavior suggests that is crucial to validate the hyper-parameters to obtain good results.

# %% [markdown]
# ### GRID Search:
#
# Since a deep net has many hyperparameters, in order to find the best ones, we have to consider all the possible combinations of all of the possible values. One common method to perform this complex task is Grid-Search.
# Given a set of values for each hyper-parameter, Grid-Search will build a model on each parameter combination possible. It iterates through every parameter combination and stores a model for each combination. Finally, the model that obtained the best result on the validation set will be select.
#
# In order to perfrom Grid-Search we will use GridSearchCV method from scikit-learn.

# %% [markdown]
# Let's Create a build_model() function that takes two arguments, n_units and learning_rate, and builds, compiles and returns a model with the given number of of neurons and the given learning rate.
# In order to limit the time demends of the proces we will consider only this two hyper-paramters and a small 3 layer model.

# %%
def build_model(n_units=30, learning_rate=1e-3):
  model = keras.models.Sequential([keras.layers.Flatten(input_shape=[28, 28]),keras.layers.Dense(n_units, activation="relu"),keras.layers.Dense(10, activation="softmax")])
  model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=learning_rate),
              metrics=["accuracy"])
  
  return model
 #To complete:
  #HINT: the function has to build the model with 3 layers:
  #- a Flatten layer to convert each 28x28 image to a single row 
  #- a Danse layer composed of n_units and that exploits Relu activation function 
  #- the output layer that uses the softmax activation function
  #Then, has to be defined how the model will be compiled.
    
#Create a keras.wrappers.scikit_learn.KerasRegressor and pass the build_model 
#function to the constructor. This gives you a Scikit-Learn compatible predictor
keras_reg = keras.wrappers.scikit_learn.KerasRegressor(build_model)

# %% [markdown]
# Let's define the lists of hyper-parameters' values. Also in this case, we use a very limited size lists, but in a real-world scenario a reasonable amount of possible values should be considered (try to add some values and check how much the time required to perform the Grid-Search increases)

# %%
param_distribs = {
    "n_units": [10,20,50],                         # To_complete: insert a few (2 or 3) reasonable values  
    "learning_rate": [1e-4, 1e-3]                             # To_complete: insert a few (2 or 3) reasonable values
}
    
    #Check how much increase the time required to perform GRID search increasing
    #the number of the values for each hyper-parameter.

# %% [markdown]
# Use a sklearn.model_selection.GridSearchCV to search the hyperparameter space of your KerasRegressor

# %%
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(keras_reg, param_distribs)

# %% [markdown]
# Run the Grid-Search

# %%
grid_search.fit(X_train_scaled, y_train, epochs=10, #The number of epochs can be modified (check what happens by increasing it) 
                  validation_data=(X_valid_scaled, y_valid))
# Out:
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.8657 - accuracy: 0.7244 - val_loss: 0.8353 - val_accuracy: 0.7350
# Epoch 10/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.8358 - accuracy: 0.7321 - val_loss: 0.8085 - val_accuracy: 0.7414
# 344/344 [==============================] - 0s 1ms/step - loss: 0.8122 - accuracy: 0.7345
# Epoch 1/10
#  415/1375 [========>.....................] - ETA: 1s - loss: 2.5100 - accuracy: 0.1724
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-142-8db9fefb7112> in <module>()
#       1 grid_search.fit(X_train_scaled, y_train, epochs=10, #The number of epochs can be modified (check what happens by increasing it)
# ----> 2                   validation_data=(X_valid_scaled, y_valid))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# -> 1151         evaluate_candidates(ParameterGrid(self.param_grid))
#    1152
#    1153
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     687                                for parameters, (train, test)
#     688                                in product(candidate_params,
# --> 689                                           cv.split(X, y, groups)))
#     690
#     691                 if len(out) < 1:
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# -> 1007             while self.dispatch_one_batch(iterator):
#    1008                 pass
#    1009
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     513             estimator.fit(X_train, **fit_params)
#     514         else:
# --> 515             estimator.fit(X_train, y_train, **fit_params)
#     516
#     517     except Exception as e:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/wrappers/scikit_learn.py in fit(self, x, y, **kwargs)
#     164     fit_args.update(kwargs)
#     165
# --> 166     history = self.model.fit(x, y, **fit_args)
#     167
#     168     return history
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     790                 context.async_wait()
#     791               logs = tmp_logs  # No error, now safe to assign to logs.
# --> 792               callbacks.on_train_batch_end(step, logs)
#     793         epoch_logs = copy.copy(logs)
#     794
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     388     if self._should_call_train_batch_hooks:
#     389       logs = self._process_logs(logs)
# --> 390       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     391
#     392   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     299     self._delta_ts[hook_name].append(time.time() - t_before_callbacks)
#     300
# --> 301     delta_t_median = np.median(self._delta_ts[hook_name])
#     302     if (self._delta_t_batch > 0. and
#     303         delta_t_median > 0.95 * self._delta_t_batch and delta_t_median > 0.1):
#
# <__array_function__ internals> in median(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py in median(a, axis, out, overwrite_input, keepdims)
#    3493     """
#    3494     r, k = _ureduce(a, func=_median, axis=axis, out=out,
# -> 3495                     overwrite_input=overwrite_input)
#    3496     if keepdims:
#    3497         return r.reshape(k)
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py in _ureduce(a, func, **kwargs)
#    3401         keepdim = (1,) * a.ndim
#    3402
# -> 3403     r = func(a, **kwargs)
#    3404     return r, keepdim
#    3405
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py in _median(a, axis, out, overwrite_input)
#    3515         kth = [(sz - 1) // 2]
#    3516     # Check if the array contains any nan's
# -> 3517     if np.issubdtype(a.dtype, np.inexact):
#    3518         kth.append(-1)
#    3519
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/numerictypes.py in issubdtype(arg1, arg2)
#     390
#     391     """
# --> 392     if not issubclass_(arg1, generic):
#     393         arg1 = dtype(arg1).type
#     394     if not issubclass_(arg2, generic):
#
# KeyboardInterrupt:

# %% [markdown]
# Print the best hyper-parameters, and evealuate the best model on the test set.

# %%
print(grid_search.best_params_)

model = grid_search.best_estimator_.model
model.evaluate(X_test_scaled, y_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-139-81733eda72e0> in <module>()
# ----> 1 print(grid_search.best_params_)
#       2
#       3 model = grid_search.best_estimator_.model
#       4 model.evaluate(X_test_scaled, y_test)
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'
