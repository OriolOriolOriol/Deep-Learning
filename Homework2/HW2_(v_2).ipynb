# %% [markdown]
# #**HW 2: Optimize and train Deep Models**
#
# In this homework, we will explore how to develop a simple Deep Neural Network for image classification. We will explore two common libraries: TensorFlow and Keras.
# Then we will explore how to face a well know problem that is common to encounter during the training phase: the Overfitting.
# Finally, we will study how to perform a fair model selection.
# Hint: Before starting the exercise take a look at how Tensorflow and Keras are designed.

# %% [markdown]
# ##Exercise 2.1: Image Classficiation with Tensorflow and Keras
#
# In this first exercise we will develop a 3 layer Neural Network to perfrom image classification.
#
# Let's start importing the libraries we will need and setting a couple of environmental variables.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sklearn
import sys
import tensorflow as tf
from tensorflow import keras  # tf.keras
import time

#Set the log level in order to hide the unuseful warnings
import logging
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3" 

tf.random.set_seed(42)

# %% [markdown]
# ### Load Data: Fashion MNIST dataset
#
# We will use the Fashion MNIST dataset, a dataset of Zalando's articles. Each sample is a 28x28 pixels grayscale image, associated with a label from 10 classes:
#
# class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]
#
# Each pixel intensity is represented by a uint8 (byte) from 0 to 255.
# We will divide the dataset in training, testing and validation set. As you already know, the training set will be used to train the model, the validation set will be used to perform model selection and finally, the test set will be used to asses the performance of deep network.

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = (
    fashion_mnist.load_data()) #The dataset is already divede in test and training...

#We extract the first 5000 samples of the training set, to use them as the validation set
X_valid, X_train = X_train_full[:5000], X_train_full[5000:] 
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %% [markdown]
# Let's take a look at a sample of the images in the dataset:

# %%
n_rows = 5
n_cols = 10
plt.figure(figsize=(n_cols*1.4, n_rows * 1.6))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train[index], cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(class_names[y_train[index]])
plt.show()

# %% [markdown]
# ### Define the model:
#
# Let's build a Sequential model (keras.models.Sequential) and add four layers to it by calling its add() method:
#
#
# *  we start with a Flatten layer (keras.layers.Flatten) to convert each 28x28 image to a single row of 784 pixel values. Since it is the first layer in your model, you should specify the input_shape argument, leaving out the batch size: [28, 28];
# *  a Dense layer (keras.layers.Dense) with 300 neurons, and the "relu" activation function;
# * another Dense layer with 100 neurons, also with the "relu" activation function;
# * a final Dense layer with 10 output neurons (one per class), and with the "softmax" activation function to ensure that the sum of all the estimated class probabilities for each image is equal to 1.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
model.add(keras.layers.Dense(300, activation="relu"))
model.add(keras.layers.Dense(100, activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))

# %% [markdown]
# Call the model's summary() method to check if the model has been built correctly. Also, try using keras.utils.plot_model() to save an image of your model's architecture.

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_6 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 300)               235500
# _________________________________________________________________
# dense_19 (Dense)             (None, 100)               30100
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model, "my_mnist_model.png", show_shapes=True)

# %% [markdown]
# As you can see, the first dimension of each layer is not defined (?), indeed this dimension in each layer is variable and depends on the batch size.

# %% [markdown]
# ### Optimize the model:
#
# After the model has been created, you must call its compile() method to specify the loss function and the optimizer to use.
#
# The conventional way is to have the target outputs to match the output shape. In this case that would mean to convert the targets to the one-hot encoded array to match with the output shape.
# However, with the help of the sparse_categorical_crossentropy loss function, we can skip that step and keep the integers as targets.
#
#  In this case, we want to use the "sparse_categorical_crossentropy" loss, and the SGD optimizer (stochastic gradient descent).
#
#
#
# Moreover, you can optionally specify a list of additional metrics that should be measured during training. In this case we specify metrics=["accuracy"].

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=1e-3),
              metrics=["accuracy"])

# %% [markdown]
# Now our model is ready to be trained. Call its fit() method, passing to it the input features (X_train) and the target classes (y_train). Set the number of epoch to 20.
# In order to validate our model we will also pass the validation data by setting validation_data=(X_valid, y_valid). Keras will compute the loss and the additional metrics (the accuracy in this case) on the validation set at the end of each epoch. If the loss on the training set is much lower than the one on the validation set, your model is probably overfitting the training set. Note: the fit() method will return a History object containing training stats.

# %%
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 2.4610 - accuracy: 0.7195 - val_loss: 0.6724 - val_accuracy: 0.7664
# Epoch 2/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5560 - accuracy: 0.7993 - val_loss: 0.5232 - val_accuracy: 0.8206
# Epoch 3/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4885 - accuracy: 0.8192 - val_loss: 0.5421 - val_accuracy: 0.8116
# Epoch 4/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4534 - accuracy: 0.8325 - val_loss: 0.4822 - val_accuracy: 0.8244
# Epoch 5/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4294 - accuracy: 0.8409 - val_loss: 0.4510 - val_accuracy: 0.8422
# Epoch 6/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4113 - accuracy: 0.8475 - val_loss: 0.4634 - val_accuracy: 0.8450
# Epoch 7/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3966 - accuracy: 0.8532 - val_loss: 0.4514 - val_accuracy: 0.8470
# Epoch 8/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3858 - accuracy: 0.8562 - val_loss: 0.4767 - val_accuracy: 0.8364
# Epoch 9/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3742 - accuracy: 0.8606 - val_loss: 0.4331 - val_accuracy: 0.8504
# Epoch 10/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3653 - accuracy: 0.8643 - val_loss: 0.4286 - val_accuracy: 0.8558
# Epoch 11/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3564 - accuracy: 0.8663 - val_loss: 0.4188 - val_accuracy: 0.8606
# Epoch 12/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3499 - accuracy: 0.8693 - val_loss: 0.4217 - val_accuracy: 0.8580
# Epoch 13/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3427 - accuracy: 0.8709 - val_loss: 0.4269 - val_accuracy: 0.8574
# Epoch 14/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3383 - accuracy: 0.8734 - val_loss: 0.4341 - val_accuracy: 0.8548
# Epoch 15/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3307 - accuracy: 0.8756 - val_loss: 0.4137 - val_accuracy: 0.8640
# Epoch 16/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3272 - accuracy: 0.8782 - val_loss: 0.4233 - val_accuracy: 0.8628
# Epoch 17/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3232 - accuracy: 0.8792 - val_loss: 0.4339 - val_accuracy: 0.8562
# Epoch 18/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3169 - accuracy: 0.8805 - val_loss: 0.4270 - val_accuracy: 0.8652
# Epoch 19/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3128 - accuracy: 0.8829 - val_loss: 0.4121 - val_accuracy: 0.8688
# Epoch 20/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3082 - accuracy: 0.8839 - val_loss: 0.4244 - val_accuracy: 0.8594

# %% [markdown]
# Let's plot the loss and the accuracy trends on both training and validation sets. We define the "plot_learning_curves" because we will reuse it in the next steps.

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 1)
    plt.show()
plot_learning_curves(history)

# %% [markdown]
# ### Evaluate the model:
#
# Now, our model has been optimized on the training set, and as you can see the performance on the validation set in quite similar (so it does not overfit the training data). Let's now evaluate the performance of our model using the test set.

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 0s 2ms/step - loss: 0.4747 - accuracy: 0.8357
# [0.4746619760990143, 0.8356999754905701]

# %% [markdown]
# ### Input normalization:
#
# When using Gradient Descent, it is usually a good idea to ensure that all the features have a similar scale. It's a common practice to scale your data inputs to have zero mean and unit variance. This is known as the standard scaler approach.
# Try to standardize the pixel values and see if this improves the performance of your neural network.

# %%
###########################################################################
#It would be problematic to feed a neural network values that employ such different scales of values. 
#The network can also adapt to such heterogeneous data, but learning would be much more difficult. 
#A widely used best practice for considering such disparate data is to apply normalization to it. 
#For each characteristic in the input data, you subtract the average of the characteristic 
#and divide it by the standard deviation, so that the characteristic is centered on 0 and has a unitary standard deviation. 

mean = X_train.mean(axis=0)
std = X_train.std(axis=0) 

X_train_scaled = (X_train - mean) / std 
X_valid_scaled = (X_valid - mean) / std
X_test_scaled = (X_test - mean) / std
#############################################################################
#Another method that I used is, before the training, 
#we pre-process the data by reconfiguring it in the form expected by the network and scaling it so that all values are within the range [0.1].

#X_train_scaled = X_train.astype('float32') /255
#X_valid_scaled = X_valid.astype('float32') /255
#X_test_scaled = X_test.astype('float32') /255



#Alternatively, you can use Scikit-Learn's StandardScaler...

# %% [markdown]
# Let's define the model in order to re-initialize the weights and then train it by using the normalize data.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
model.add(keras.layers.Dense(300, activation="relu"))
model.add(keras.layers.Dense(100, activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=1e-3),
              metrics=["accuracy"])

history = model.fit(X_train_scaled, y_train, epochs=20,
                    validation_data=(X_valid_scaled, y_valid))
print("Model Evaluation")
model.evaluate(X_test_scaled, y_test)
plot_learning_curves(history)
# Out:
# Epoch 1/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.9390 - accuracy: 0.6949 - val_loss: 0.6299 - val_accuracy: 0.7850
# Epoch 2/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5797 - accuracy: 0.7997 - val_loss: 0.5264 - val_accuracy: 0.8114
# Epoch 3/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5077 - accuracy: 0.8214 - val_loss: 0.4825 - val_accuracy: 0.8300
# Epoch 4/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4691 - accuracy: 0.8342 - val_loss: 0.4531 - val_accuracy: 0.8412
# Epoch 5/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4437 - accuracy: 0.8440 - val_loss: 0.4353 - val_accuracy: 0.8470
# Epoch 6/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4247 - accuracy: 0.8503 - val_loss: 0.4216 - val_accuracy: 0.8520
# Epoch 7/20
# 1719/1719 [==============================] - 4s 3ms/step - loss: 0.4097 - accuracy: 0.8559 - val_loss: 0.4099 - val_accuracy: 0.8552
# Epoch 8/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3973 - accuracy: 0.8599 - val_loss: 0.4025 - val_accuracy: 0.8596
# Epoch 9/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3867 - accuracy: 0.8640 - val_loss: 0.3935 - val_accuracy: 0.8622
# Epoch 10/20
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.3773 - accuracy: 0.8675 - val_loss: 0.3881 - val_accuracy: 0.8618
# Epoch 11/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3693 - accuracy: 0.8703 - val_loss: 0.3820 - val_accuracy: 0.8656
# Epoch 12/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3619 - accuracy: 0.8732 - val_loss: 0.3773 - val_accuracy: 0.8660
# Epoch 13/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3553 - accuracy: 0.8757 - val_loss: 0.3718 - val_accuracy: 0.8690
# Epoch 14/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3492 - accuracy: 0.8773 - val_loss: 0.3690 - val_accuracy: 0.8688
# Epoch 15/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3435 - accuracy: 0.8793 - val_loss: 0.3657 - val_accuracy: 0.8690
# Epoch 16/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3381 - accuracy: 0.8813 - val_loss: 0.3612 - val_accuracy: 0.8724
# Epoch 17/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3332 - accuracy: 0.8821 - val_loss: 0.3588 - val_accuracy: 0.8722
# Epoch 18/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3284 - accuracy: 0.8846 - val_loss: 0.3552 - val_accuracy: 0.8732
# Epoch 19/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3241 - accuracy: 0.8852 - val_loss: 0.3543 - val_accuracy: 0.8754
# Epoch 20/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3199 - accuracy: 0.8861 - val_loss: 0.3503 - val_accuracy: 0.8762
# Model Evaluation
# 313/313 [==============================] - 0s 2ms/step - loss: 0.3809 - accuracy: 0.8636

# %% [markdown]
# Note that the validation curve is smoother than in the previous test and it is also more simlar to the training curve.

# %% [markdown]
# ## Exercise 2.2: Overfiting
#
# A common problem that occurs when you train a deep neural network is overfittig. Overfitting occurs when you achieve a good fit of your model on the training data, while it does not generalize well on new, unseen data. In other words, the model learned patterns specific to the training data, which are irrelevant in other data.
# As we have seen in the previous exercise, our model does not overfit the training data. In this exercise, we try to modify the training parameters in order to have a model that overfits.
# Overfitting can have many causes and usually is a combination of some of them, for instance: too many parameters/ layers, too few training samples, wrong learning rate (usualy too high), etc..

# %%
#To complete: modify the previuos model in order to obtain  a new mdel that overfit the training data
#HINT: A model tends to overfit when too few training examples are available
X_train_small = X_train_full[:600]
y_train_small = y_train_full[:600]

#To complete: Add layers
#HINT: A model tends to overfit  when the number of learnable parameters is very high compared to the number of training samples
#HINT: Is it possible to use different activation functions than ReLu
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
#model.add(keras.layers.Dense(300, activation="relu"))
for i in range(10):
  model.add(keras.layers.Dense(50, activation="relu"))

model.add(keras.layers.Dense(10, activation="softmax"))


model.compile(loss="sparse_categorical_crossentropy",optimizer=keras.optimizers.SGD(lr=1e-2),metrics=['accuracy']) #To complete:learning rate

#HINT: A model tends to overfit when the number of training epochs is high
history = model.fit(X_train_small, y_train_small, epochs=100,validation_data=(X_valid, y_valid))
print("Model Evaluation")
model.evaluate(X_test, y_test)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 0s 20ms/step - loss: 3.1107 - accuracy: 0.1833 - val_loss: 2.0765 - val_accuracy: 0.2746
# Epoch 2/100
# 19/19 [==============================] - 0s 13ms/step - loss: 1.8734 - accuracy: 0.3333 - val_loss: 1.7290 - val_accuracy: 0.4002
# Epoch 3/100
# 19/19 [==============================] - 0s 13ms/step - loss: 1.5721 - accuracy: 0.4800 - val_loss: 1.5519 - val_accuracy: 0.4802
# Epoch 4/100
# 19/19 [==============================] - 0s 13ms/step - loss: 1.3818 - accuracy: 0.5400 - val_loss: 1.3955 - val_accuracy: 0.5350
# Epoch 5/100
# 19/19 [==============================] - 0s 14ms/step - loss: 1.2374 - accuracy: 0.5933 - val_loss: 1.3161 - val_accuracy: 0.5430
# Epoch 6/100
# 19/19 [==============================] - 0s 13ms/step - loss: 1.1193 - accuracy: 0.6333 - val_loss: 1.2095 - val_accuracy: 0.5728
# Epoch 7/100
# 19/19 [==============================] - 0s 13ms/step - loss: 1.0492 - accuracy: 0.6533 - val_loss: 1.2099 - val_accuracy: 0.5804
# Epoch 8/100
# 19/19 [==============================] - 0s 13ms/step - loss: 0.9666 - accuracy: 0.6817 - val_loss: 1.1076 - val_accuracy: 0.6164
# Epoch 9/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.8663 - accuracy: 0.7167 - val_loss: 1.0604 - val_accuracy: 0.6340
# Epoch 10/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.8390 - accuracy: 0.7217 - val_loss: 1.0164 - val_accuracy: 0.6482
# Epoch 11/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.8119 - accuracy: 0.7283 - val_loss: 0.9844 - val_accuracy: 0.6540
# Epoch 12/100
# 19/19 [==============================] - 0s 13ms/step - loss: 0.7194 - accuracy: 0.7750 - val_loss: 0.9835 - val_accuracy: 0.6566
# Epoch 13/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0
100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0814 - accuracy: 0.9850 - val_loss: 1.0264 - val_accuracy: 0.7470
# Epoch 74/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0930 - accuracy: 0.9800 - val_loss: 0.9702 - val_accuracy: 0.7572
# Epoch 75/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0721 - accuracy: 0.9883 - val_loss: 0.9907 - val_accuracy: 0.7518
# Epoch 76/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0654 - accuracy: 0.9967 - val_loss: 1.0136 - val_accuracy: 0.7482
# Epoch 77/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0770 - accuracy: 0.9883 - val_loss: 0.9984 - val_accuracy: 0.7518
# Epoch 78/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0654 - accuracy: 0.9917 - val_loss: 1.0001 - val_accuracy: 0.7548
# Epoch 79/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0597 - accuracy: 0.9967 - val_loss: 0.9783 - val_accuracy: 0.7596
# Epoch 80/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0766 - accuracy: 0.9850 - val_loss: 0.9869 - val_accuracy: 0.7580
# Epoch 81/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0557 - accuracy: 0.9967 - val_loss: 0.9933 - val_accuracy: 0.7588
# Epoch 82/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0555 - accuracy: 0.9983 - val_loss: 1.0105 - val_accuracy: 0.7530
# Epoch 83/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0582 - accuracy: 0.9967 - val_loss: 1.0049 - val_accuracy: 0.7558
# Epoch 84/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0478 - accuracy: 0.9983 - val_loss: 1.0134 - val_accuracy: 0.7576
# Epoch 85/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0506 - accuracy: 0.9983 - val_loss: 1.0415 - val_accuracy: 0.7562
# Epoch 86/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0462 - accuracy: 0.9983 - val_loss: 1.0346 - val_accuracy: 0.7564
# Epoch 87/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0466 - accuracy: 0.9983 - val_loss: 1.0356 - val_accuracy: 0.7580
# Epoch 88/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0547 - accuracy: 0.9950 - val_loss: 1.0332 - val_accuracy: 0.7582
# Epoch 89/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0483 - accuracy: 0.9967 - val_loss: 1.0332 - val_accuracy: 0.7576
# Epoch 90/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0431 - accuracy: 0.9983 - val_loss: 1.0572 - val_accuracy: 0.7522
# Epoch 91/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0432 - accuracy: 0.9983 - val_loss: 1.0334 - val_accuracy: 0.7602
# Epoch 92/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0406 - accuracy: 0.9983 - val_loss: 1.0591 - val_accuracy: 0.7578
# Epoch 93/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0411 - accuracy: 0.9983 - val_loss: 1.0424 - val_accuracy: 0.7600
# Epoch 94/100
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0388 - accuracy: 0.9983 - val_loss: 1.0589 - val_accuracy: 0.7586
# Epoch 95/100
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0360 - accuracy: 0.9983 - val_loss: 1.0728 - val_accuracy: 0.7564
# Epoch 96/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0364 - accuracy: 0.9983 - val_loss: 1.0616 - val_accuracy: 0.7602
# Epoch 97/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0349 - accuracy: 0.9983 - val_loss: 1.0771 - val_accuracy: 0.7596
# Epoch 98/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0336 - accuracy: 0.9983 - val_loss: 1.0817 - val_accuracy: 0.7578
# Epoch 99/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0337 - accuracy: 1.0000 - val_loss: 1.0886 - val_accuracy: 0.7580
# Epoch 100/100
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0331 - accuracy: 1.0000 - val_loss: 1.0884 - val_accuracy: 0.7562
# Model Evaluation
# 313/313 [==============================] - 0s 1ms/step - loss: 1.3127 - accuracy: 0.7049
# [1.3126764297485352, 0.7049000263214111]

# %% [markdown]
# Define the plot_learning_loss function and plot the loss and val_loss trends

# %%
def plot_learning_loss(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.show()
plot_learning_loss(history)
#######################################
#I added this function to see the function's behaviour between [0,1] in particular the accuracy metric
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 1)
    plt.show()
plot_learning_curves(history)

# %% [markdown]
# ### L1-norm
#
# One possible way to solve the overitting issue is by using regularization methods. The two most common regularization methods in Deep Learning are the L1-norm regularization and the L2-norm regularization. Both These techniques are based on limiting the capacity of models, by adding a parameter norm penalty to the objective function $\mathcal{J}$:
# $$
# \hat{\mathcal{J}}(\theta,\mathbf{X},\mathbf{y}) = \mathcal{J}(\theta,\mathbf{X},\mathbf{y}) + \alpha \Omega(\theta)
# $$
# where $\alpha$ is a hyperparameter that weighs the relative contribution of the norm penalty $\Omega$.
# Lets start by considering the L1-norm regularization where the regularization term is defined as:
# $$
#  \Omega(\theta)=||\mathbf{W}||_1=\sum_i |\mathbf{w}|
# $$
# Let's find the values for the $\alpha$ parameters that allow removing remove the overfitting effect.

# %%
#####################################################################################################################
#Why we use the regularization?

#Let's consider Occam's razor principle: give two explanations for something, the simplest one tends to be also the most correct. 
#This idea applies also to the models learned from neural networks: training data and a network architecture, there are many value sets of weights (and therefore models) 
#able to "explain" the data. The simpler models tend to suffer less overfits than the complex ones.
#A simple model is such that the distribution of parameter values has less entropy. 
#Therefore, a common way to mitigate overfitting is to impose constraints on the complexity of the network by forcing its weights to assume only small values 
#that make the distribution of the values of the weights more regular. 
#The regularization of weights is carried out by adding to the objective function of the network a cost associated with the presence of large weights.
#########################################################################################################################

#Regularization L1: the added cost is proportional to the absolute value of the weight coefficients.
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
for i in range(10):
  model.add(keras.layers.Dense(50, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(0.005))) 
#model.add(keras.layers.Dense(100, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(0.05))) 
#model.add(keras.layers.Dense(90, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(0.05))) 
#model.add(keras.layers.Dense(80, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(0.05))) 
#model.add(keras.layers.Dense(70, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(0.05))) 
#model.add(keras.layers.Dense(60, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(0.05))) 
model.add(keras.layers.Dense(10, activation="softmax")) 


model.compile(loss="sparse_categorical_crossentropy", optimizer=keras.optimizers.SGD(lr=0.0001),metrics=['accuracy']) 


history = model.fit(X_train_small, y_train_small, epochs=50, #To complete: number of epochs
                    validation_data=(X_valid, y_valid))
print("Model Evaluation")
model.evaluate(X_test, y_test)
plot_learning_loss(history)
#I recall this function plot to see the accuracy
plot_learning_curves(history)
# Out:
# Epoch 1/50
# 19/19 [==============================] - 0s 23ms/step - loss: 25.4837 - accuracy: 0.1117 - val_loss: 25.1897 - val_accuracy: 0.1178
# Epoch 2/50
# 19/19 [==============================] - 0s 14ms/step - loss: 25.0569 - accuracy: 0.1117 - val_loss: 24.9301 - val_accuracy: 0.1176
# Epoch 3/50
# 19/19 [==============================] - 0s 14ms/step - loss: 24.8570 - accuracy: 0.1117 - val_loss: 24.7846 - val_accuracy: 0.1256
# Epoch 4/50
# 19/19 [==============================] - 0s 14ms/step - loss: 24.7302 - accuracy: 0.1100 - val_loss: 24.6888 - val_accuracy: 0.1330
# Epoch 5/50
# 19/19 [==============================] - 0s 14ms/step - loss: 24.6393 - accuracy: 0.1267 - val_loss: 24.6156 - val_accuracy: 0.1452
# Epoch 6/50
# 19/19 [==============================] - 0s 14ms/step - loss: 24.5625 - accuracy: 0.1467 - val_loss: 24.5548 - val_accuracy: 0.1576
# Epoch 7/50
# 19/19 [==============================] - 0s 14ms/step - loss: 24.4955 - accuracy: 0.1600 - val_loss: 24.5040 - val_accuracy: 0.1692
# Epoch 8/50
# 19/19 [==============================] - 0s 14ms/step - loss: 24.4413 - accuracy: 0.1717 - val_loss: 24.4564 - val_accuracy: 0.1844
# Epoch 9/50
# 19/19 [==============================] - 0s 14ms/step - loss: 24.3865 - accuracy: 0.1900 - val_loss: 24.4144 - val_accuracy: 0.1986
# Epoch 10/50
# 19/19 [==============================] - 0s 15ms/step - loss: 24.3438 - accuracy: 0.2050 - val_loss: 24.3759 - val_accuracy: 0.2146
# Epoch 11/50
# 19/19 [==============================] - 0s 15ms/step - loss: 24.2998 - accuracy: 0.2267 - val_loss: 24.3402 - val_accuracy: 0.2268
# Epoch 12/50
# 19/19 [==============================] - 0s 14ms/step - loss: 24.2596 - accuracy: 0.2500 - val_loss: 24.3065 - val_accuracy: 0.2384
# Epoch 13/50
# 19/19 [==============================] - 0s 14ms/step - loss: 24.2159 - accuracy: 0.2583 - val_loss: 24.2763 - val_accuracy: 0.2486
# Epoch 14/50
# 19/19 [==============================] - 0s 14ms/step - loss: 24.1833 - accuracy: 0.2783 - val_loss: 24.2470 - val_accuracy: 0.2590
# Epoch 15/50
# 19/19 [==============================] - 0s 14ms/step - loss: 24.1488 - accuracy: 0.2900 - val_loss: 24.2175 - val_accuracy: 0.2676
# Epoch 16/50
# 19/19 [==============================] - 0s 14ms/step - loss: 24
50
# 19/19 [==============================] - 0s 14ms/step - loss: 23.4802 - accuracy: 0.4983 - val_loss: 23.6720 - val_accuracy: 0.4236
# Epoch 44/50
# 19/19 [==============================] - 0s 15ms/step - loss: 23.4674 - accuracy: 0.5100 - val_loss: 23.6613 - val_accuracy: 0.4262
# Epoch 45/50
# 19/19 [==============================] - 0s 14ms/step - loss: 23.4474 - accuracy: 0.5117 - val_loss: 23.6493 - val_accuracy: 0.4286
# Epoch 46/50
# 19/19 [==============================] - 0s 14ms/step - loss: 23.4335 - accuracy: 0.5200 - val_loss: 23.6354 - val_accuracy: 0.4300
# Epoch 47/50
# 19/19 [==============================] - 1s 28ms/step - loss: 23.4145 - accuracy: 0.5300 - val_loss: 23.6239 - val_accuracy: 0.4322
# Epoch 48/50
# 19/19 [==============================] - 0s 14ms/step - loss: 23.4026 - accuracy: 0.5350 - val_loss: 23.6093 - val_accuracy: 0.4354
# Epoch 49/50
# 19/19 [==============================] - 0s 14ms/step - loss: 23.3889 - accuracy: 0.5267 - val_loss: 23.5986 - val_accuracy: 0.4364
# Epoch 50/50
# 19/19 [==============================] - 0s 14ms/step - loss: 23.3731 - accuracy: 0.5350 - val_loss: 23.5871 - val_accuracy: 0.4404
# Model Evaluation
# 313/313 [==============================] - 0s 1ms/step - loss: 23.6389 - accuracy: 0.4066

# %% [markdown]
# ### L2-norm
#
# L2-norm regularization is also known as weight decay. This strategy drives the weights closer to the origin by adding the regularization term omega which is defined as:
# $$
#  \Omega(\theta)=\frac{1}{2}||\mathbf{W}||_2^2
# $$
#
# Let's find the values for the $\alpha$ parameters that allow removing remove the overfitting effect with L2-norm.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))

#Regularisation L2: the added cost is proportional to the square of the value of the weight coefficients. 

#model.add(keras.layers.Dense(300, activation="relu",kernel_regularizer=tf.keras.regularizers.l2(1e-4))) 
#for i in range(10):
  #model.add(keras.layers.Dense(100, activation="relu",kernel_regularizer=tf.keras.regularizers.l2(1e-4))) 

for i in range(10):
  model.add(keras.layers.Dense(50, activation="relu",kernel_regularizer=tf.keras.regularizers.l2(0.05))) 
#model.add(keras.layers.Dense(100, activation="relu"))
#model.add(keras.layers.Dense(90, activation="relu"))
#model.add(keras.layers.Dense(80, activation="relu"))
#model.add(keras.layers.Dense(70, activation="relu"))
#model.add(keras.layers.Dense(60, activation="relu")) 
#model.add(keras.layers.Dense(units=50, activation="relu",kernel_regularizer=tf.keras.regularizers.l2(0.05))) 
model.add(keras.layers.Dense(10, activation="softmax")) 


model.compile(loss="sparse_categorical_crossentropy",optimizer=keras.optimizers.SGD(lr=0.0001),metrics=['accuracy']) 

history = model.fit(X_train_small, y_train_small, epochs=50, validation_data=(X_valid, y_valid))

print("Model Evaluation")
model.evaluate(X_test, y_test)
plot_learning_loss(history)
#I recall this function plot to see the accuracy
plot_learning_curves(history)
# Out:
# Epoch 1/50
# 19/19 [==============================] - 0s 24ms/step - loss: 31.6200 - accuracy: 0.1017 - val_loss: 30.3809 - val_accuracy: 0.1416
# Epoch 2/50
# 19/19 [==============================] - 0s 15ms/step - loss: 30.0138 - accuracy: 0.1533 - val_loss: 29.8071 - val_accuracy: 0.1618
# Epoch 3/50
# 19/19 [==============================] - 0s 14ms/step - loss: 29.6236 - accuracy: 0.1700 - val_loss: 29.5746 - val_accuracy: 0.1796
# Epoch 4/50
# 19/19 [==============================] - 0s 15ms/step - loss: 29.4341 - accuracy: 0.1767 - val_loss: 29.4279 - val_accuracy: 0.1908
# Epoch 5/50
# 19/19 [==============================] - 0s 15ms/step - loss: 29.3012 - accuracy: 0.1883 - val_loss: 29.3234 - val_accuracy: 0.2098
# Epoch 6/50
# 19/19 [==============================] - 0s 16ms/step - loss: 29.2045 - accuracy: 0.2183 - val_loss: 29.2386 - val_accuracy: 0.2218
# Epoch 7/50
# 19/19 [==============================] - 0s 15ms/step - loss: 29.1131 - accuracy: 0.2367 - val_loss: 29.1698 - val_accuracy: 0.2430
# Epoch 8/50
# 19/19 [==============================] - 0s 15ms/step - loss: 29.0438 - accuracy: 0.2817 - val_loss: 29.1090 - val_accuracy: 0.2556
# Epoch 9/50
# 19/19 [==============================] - 0s 14ms/step - loss: 28
50
# 19/19 [==============================] - 0s 14ms/step - loss: 28.0445 - accuracy: 0.6117 - val_loss: 28.2148 - val_accuracy: 0.5176
# Epoch 37/50
# 19/19 [==============================] - 0s 14ms/step - loss: 28.0170 - accuracy: 0.6150 - val_loss: 28.1887 - val_accuracy: 0.5254
# Epoch 38/50
# 19/19 [==============================] - 0s 14ms/step - loss: 27.9863 - accuracy: 0.6133 - val_loss: 28.1661 - val_accuracy: 0.5330
# Epoch 39/50
# 19/19 [==============================] - 0s 14ms/step - loss: 27.9599 - accuracy: 0.6417 - val_loss: 28.1399 - val_accuracy: 0.5390
# Epoch 40/50
# 19/19 [==============================] - 0s 14ms/step - loss: 27.9405 - accuracy: 0.6417 - val_loss: 28.1166 - val_accuracy: 0.5466
# Epoch 41/50
# 19/19 [==============================] - 0s 14ms/step - loss: 27.9131 - accuracy: 0.6367 - val_loss: 28.0964 - val_accuracy: 0.5522
# Epoch 42/50
# 19/19 [==============================] - 0s 15ms/step - loss: 27.8902 - accuracy: 0.6533 - val_loss: 28.0747 - val_accuracy: 0.5502
# Epoch 43/50
# 19/19 [==============================] - 0s 15ms/step - loss: 27.8634 - accuracy: 0.6433 - val_loss: 28.0508 - val_accuracy: 0.5546
# Epoch 44/50
# 19/19 [==============================] - 0s 15ms/step - loss: 27.8390 - accuracy: 0.6517 - val_loss: 28.0274 - val_accuracy: 0.5562
# Epoch 45/50
# 19/19 [==============================] - 0s 14ms/step - loss: 27.8183 - accuracy: 0.6600 - val_loss: 28.0060 - val_accuracy: 0.5692
# Epoch 46/50
# 19/19 [==============================] - 0s 14ms/step - loss: 27.7934 - accuracy: 0.6683 - val_loss: 27.9864 - val_accuracy: 0.5728
# Epoch 47/50
# 19/19 [==============================] - 0s 14ms/step - loss: 27.7679 - accuracy: 0.6667 - val_loss: 27.9639 - val_accuracy: 0.5720
# Epoch 48/50
# 19/19 [==============================] - 0s 14ms/step - loss: 27.7470 - accuracy: 0.6683 - val_loss: 27.9489 - val_accuracy: 0.5664
# Epoch 49/50
# 19/19 [==============================] - 0s 14ms/step - loss: 27.7298 - accuracy: 0.6750 - val_loss: 27.9222 - val_accuracy: 0.5762
# Epoch 50/50
# 19/19 [==============================] - 0s 16ms/step - loss: 27.7021 - accuracy: 0.6750 - val_loss: 27.9046 - val_accuracy: 0.5798
# Model Evaluation
# 313/313 [==============================] - 0s 1ms/step - loss: 27.9670 - accuracy: 0.5509

# %% [markdown]
# ### Early stopping
#
# Early Stopping is a form of regularization used to avoid overfitting. It is designed to monitor the generalization error of one model and stop training when generalization error begins to degrade. In order to evaluate the generalization error, early stopping requires that a validation dataset is evaluated during training. Then, when the validation error does not improve for a specific number of epochs (patience hyper-parameter), it stops the training phase.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
for i in range(10):
  model.add(keras.layers.Dense(50, activation="relu")) 
model.add(keras.layers.Dense(10, activation="softmax"))


model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=1e-2)) #To complete: learning rate

#Let's define a log dir in order to save the checkpoint file
logdir = os.path.join(os.curdir, "my_logs", "run_{}".format(time.time()))

#In Keras the Eraly stopping is manage by using the callbacks argument.
callbacks = [
    keras.callbacks.TensorBoard(logdir),
    keras.callbacks.EarlyStopping(patience=10), #To complete: play with patience and find the value that prevents the model from overfitting
    #Saving the checkpoints file allows to load the "best" model when the Early 
    #stopping detect that the generalization error degrade (after 'patience' epochs)
    keras.callbacks.ModelCheckpoint("my_mnist_model.h5", save_best_only=True),
]

history = model.fit(X_train_small, y_train_small, epochs=500, #To complete: number of epochs
                    validation_data=(X_valid_scaled, y_valid),
                    callbacks=callbacks)

print("Model Evaluation")
#The early stopping stopped training after few epochs without progress, so your
#model may already have started to overfit the training set. Since the 
#ModelCheckpoint callback only saved the best models (on the validation set) the
#last saved model is the best on the validation set.
model = keras.models.load_model("my_mnist_model.h5")
model.evaluate(X_test, y_test)
plot_learning_loss(history)
# Out:
# Epoch 1/500
# 19/19 [==============================] - 0s 23ms/step - loss: 2.3182 - val_loss: 2.2989
# Epoch 2/500
# 19/19 [==============================] - 0s 15ms/step - loss: 1.9771 - val_loss: 2.2951
# Epoch 3/500
# 19/19 [==============================] - 0s 16ms/step - loss: 1.6042 - val_loss: 2.2922
# Epoch 4/500
# 19/19 [==============================] - 0s 16ms/step - loss: 1.4099 - val_loss: 2.2889
# Epoch 5/500
# 19/19 [==============================] - 0s 15ms/step - loss: 1.3694 - val_loss: 2.2882
# Epoch 6/500
# 19/19 [==============================] - 0s 15ms/step - loss: 1.2379 - val_loss: 2.2837
# Epoch 7/500
# 19/19 [==============================] - 0s 16ms/step - loss: 1.0632 - val_loss: 2.2831
# Epoch 8/500
# 19/19 [==============================] - 0s 16ms/step - loss: 1.0545 - val_loss: 2.2809
# Epoch 9/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.9101 - val_loss: 2.2772
# Epoch 10/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.9167 - val_loss: 2.2762
# Epoch 11/500
# 19/19 [==============================] - 0s 13ms/step - loss: 1.3290 - val_loss: 2.2787
# Epoch 12/500
# 19/19 [==============================] - 0s 15ms/step - loss: 1.0614 - val_loss: 2.2682
# Epoch 13/500
# 19/19 [==============================] - 0s 16ms/step - loss: 0.9566 - val_loss: 2.2666
# Epoch 14/500
# 19/19 [==============================] - 0s 16ms/step - loss: 0.7918 - val_loss: 2.2609
# Epoch 15/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.7241 - val_loss: 2.2603
# Epoch 16/500
# 19/19 [==============================] - 0s 16ms/step - loss: 0.6263 - val_loss: 2.2579
# Epoch 17/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.6408 - val_loss: 2.2583
# Epoch 18/500
# 19/19 [==============================] - 0s 16ms/step - loss: 0.8014 - val_loss: 2.2560
# Epoch 19/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.5840 - val_loss: 2.2505
# Epoch 20/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.5759 - val_loss: 2.2496
# Epoch 21/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.5642 - val_loss: 2.2525
# Epoch 22/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.5093 - val_loss: 2.2472
# Epoch 23/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.5114 - val_loss: 2.2530
# Epoch 24/500
# 19/19 [==============================] - 0s 16ms/step - loss: 0.5357 - val_loss: 2.2518
# Epoch 25/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.4550 - val_loss: 2.2486
# Epoch 26/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.4766 - val_loss: 2.2488
# Epoch 27/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.4214 - val_loss: 2.2455
# Epoch 28/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.3983 - val_loss: 2.2462
# Epoch 29/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.4977 - val_loss: 2.2433
# Epoch 30/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.4603 - val_loss: 2.2465
# Epoch 31/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.4524 - val_loss: 2.2462
# Epoch 32/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.4123 - val_loss: 2.2436
# Epoch 33/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.6322 - val_loss: 2.2520
# Epoch 34/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.4487 - val_loss: 2.2444
# Epoch 35/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.3725 - val_loss: 2.2387
# Epoch 36/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.3630 - val_loss: 2.2363
# Epoch 37/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.4200 - val_loss: 2.2431
# Epoch 38/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.3279 - val_loss: 2.2371
# Epoch 39/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.4472 - val_loss: 2.2349
# Epoch 40/500
# 19/19 [==============================] - 0s 14ms/step - loss: 1.1992 - val_loss: 2.2523
# Epoch 41/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.5699 - val_loss: 2.2431
# Epoch 42/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.3910 - val_loss: 2.2311
# Epoch 43/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.3288 - val_loss: 2.2291
# Epoch 44/500
# 19/19 [==============================] - 0s 16ms/step - loss: 0.4201 - val_loss: 2.2278
# Epoch 45/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.3536 - val_loss: 2.2273
# Epoch 46/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.5510 - val_loss: 2.2350
# Epoch 47/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.4888 - val_loss: 2.2341
# Epoch 48/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.3019 - val_loss: 2.2294
# Epoch 49/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.3489 - val_loss: 2.2318
# Epoch 50/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.2652 - val_loss: 2.2278
# Epoch 51/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.3427 - val_loss: 2.2233
# Epoch 52/500
# 19/19 [==============================] - 0s 16ms/step - loss: 0.2395 - val_loss: 2.2207
# Epoch 53/500
# 19/19 [==============================] - 0s 16ms/step - loss: 0.3207 - val_loss: 2.2219
# Epoch 54/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.2893 - val_loss: 2.2214
# Epoch 55/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.3722 - val_loss: 2.2247
# Epoch 56/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.2134 - val_loss: 2.2178
# Epoch 57/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.3755 - val_loss: 2.2218
# Epoch 58/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.2709 - val_loss: 2.2126
# Epoch 59/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.2729 - val_loss: 2.2161
# Epoch 60/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1516 - val_loss: 2.2134
# Epoch 61/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.3525 - val_loss: 2.2240
# Epoch 62/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.4699 - val_loss: 2.2268
# Epoch 63/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.2256 - val_loss: 2.2204
# Epoch 64/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.3102 - val_loss: 2.2147
# Epoch 65/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.2355 - val_loss: 2.2149
# Epoch 66/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.2425 - val_loss: 2.2119
# Epoch 67/500
# 19/19 [==============================] - 0s 16ms/step - loss: 0.2346 - val_loss: 2.2094
# Epoch 68/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.2042 - val_loss: 2.2107
# Epoch 69/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1604 - val_loss: 2.2120
# Epoch 70/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.2055 - val_loss: 2.2014
# Epoch 71/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.2982 - val_loss: 2.2132
# Epoch 72/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.2028 - val_loss: 2.2113
# Epoch 73/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.3349 - val_loss: 2.2114
# Epoch 74/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1355 - val_loss: 2.2017
# Epoch 75/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1191 - val_loss: 2.1991
# Epoch 76/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1488 - val_loss: 2.1971
# Epoch 77/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.3825 - val_loss: 2.2138
# Epoch 78/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1725 - val_loss: 2.2079
# Epoch 79/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1674 - val_loss: 2.2044
# Epoch 80/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1833 - val_loss: 2.1985
# Epoch 81/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1241 - val_loss: 2.1953
# Epoch 82/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1412 - val_loss: 2.1964
# Epoch 83/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.3183 - val_loss: 2.2111
# Epoch 84/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.4603 - val_loss: 2.2072
# Epoch 85/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.1126 - val_loss: 2.1982
# Epoch 86/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0737 - val_loss: 2.1925
# Epoch 87/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1594 - val_loss: 2.1957
# Epoch 88/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.2324 - val_loss: 2.2029
# Epoch 89/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.2889 - val_loss: 2.2049
# Epoch 90/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1832 - val_loss: 2.1993
# Epoch 91/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0954 - val_loss: 2.1954
# Epoch 92/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0558 - val_loss: 2.1879
# Epoch 93/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0502 - val_loss: 2.1860
# Epoch 94/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0404 - val_loss: 2.1821
# Epoch 95/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0774 - val_loss: 2.1913
# Epoch 96/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0823 - val_loss: 2.1863
# Epoch 97/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1235 - val_loss: 2.1935
# Epoch 98/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.3434 - val_loss: 2.1978
# Epoch 99/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1876 - val_loss: 2.1909
# Epoch 100/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0663 - val_loss: 2.1866
# Epoch 101/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0845 - val_loss: 2.1831
# Epoch 102/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0514 - val_loss: 2.1825
# Epoch 103/500
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0508 - val_loss: 2.1814
# Epoch 104/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0697 - val_loss: 2.1751
# Epoch 105/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0416 - val_loss: 2.1714
# Epoch 106/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0198 - val_loss: 2.1691
# Epoch 107/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0158 - val_loss: 2.1679
# Epoch 108/500
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0125 - val_loss: 2.1662
# Epoch 109/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0114 - val_loss: 2.1647
# Epoch 110/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0102 - val_loss: 2.1632
# Epoch 111/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0094 - val_loss: 2.1620
# Epoch 112/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0080 - val_loss: 2.1601
# Epoch 113/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 2.1593
# Epoch 114/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0077 - val_loss: 2.1576
# Epoch 115/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 2.1572
# Epoch 116/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0057 - val_loss: 2.1556
# Epoch 117/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 2.1548
# Epoch 118/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0046 - val_loss: 2.1535
# Epoch 119/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0536 - val_loss: 2.1578
# Epoch 120/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.8326 - val_loss: 2.2123
# Epoch 121/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.5896 - val_loss: 2.2135
# Epoch 122/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.3309 - val_loss: 2.2070
# Epoch 123/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.4951 - val_loss: 2.2081
# Epoch 124/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.2937 - val_loss: 2.1986
# Epoch 125/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.2088 - val_loss: 2.1944
# Epoch 126/500
# 19/19 [==============================] - 0s 13ms/step - loss: 0.2679 - val_loss: 2.1974
# Epoch 127/500
# 19/19 [==============================] - 0s 14ms/step - loss: 0.2339 - val_loss: 2.1924
# Epoch 128/500
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1677 - val_loss: 2.1891
# Model Evaluation
# 313/313 [==============================] - 0s 1ms/step - loss: 1.5825

# %% [markdown]
# ## Exercise 2.3: Model Selection
#
# Hyperparameters are the parameters of the learning method itself which we have to specify a priori, i.e., before model fitting. In contrast, model parameters are parameters which arise as a result of the fit. The aim of the model selection is selecting the best hyperparameters for our deep network. Finding the right hyperparameters for a model can be crucial for the model performance on given data. For istance lets consider our model trained by using different values for the learnign rate:

# %%
learning_rates = [1e-4, 1e-2, 1e-1]

# %%
histories = []
for learning_rate in learning_rates:
    model = keras.models.Sequential([
                                    keras.layers.Flatten(input_shape=[28, 28]),
                                    keras.layers.Dense(300, activation="relu"),
                                    keras.layers.Dense(10, activation="softmax")])

    model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=learning_rate),
              metrics=["accuracy"])
              
    callbacks = [keras.callbacks.EarlyStopping(patience=2)]

    history = model.fit(X_train_scaled, y_train,
                        validation_data=(X_valid_scaled, y_valid), epochs=10,
                        callbacks=callbacks)
    histories.append(history)
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 6s 3ms/step - loss: 1.8388 - accuracy: 0.3850 - val_loss: 1.2607 - val_accuracy: 0.6012
# Epoch 2/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 1.0994 - accuracy: 0.6494 - val_loss: 0.9740 - val_accuracy: 0.6884
# Epoch 3/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.9189 - accuracy: 0.7008 - val_loss: 0.8535 - val_accuracy: 0.7240
# Epoch 4/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.8285 - accuracy: 0.7273 - val_loss: 0.7830 - val_accuracy: 0.7458
# Epoch 5/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.7713 - accuracy: 0.7428 - val_loss: 0.7355 - val_accuracy: 0.7570
# Epoch 6/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.7305 - accuracy: 0.7538 - val_loss: 0.7004 - val_accuracy: 0.7648
# Epoch 7/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.6993 - accuracy: 0.7633 - val_loss: 0.6728 - val_accuracy: 0.7718
# Epoch 8/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.6743 - accuracy: 0.7700 - val_loss: 0.6503 - val_accuracy: 0.7810
# Epoch 9/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.6534 - accuracy: 0.7762 - val_loss: 0.6316 - val_accuracy: 0.7868
# Epoch 10/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.6357 - accuracy: 0.7816 - val_loss: 0.6154 - val_accuracy: 0.7920
# Epoch 1/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5132 - accuracy: 0.8214 - val_loss: 0.4002 - val_accuracy: 0.8630
# Epoch 2/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3774 - accuracy: 0.8669 - val_loss: 0.3616 - val_accuracy: 0.8768
# Epoch 3/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3411 - accuracy: 0.8795 - val_loss: 0.3603 - val_accuracy: 0.8730
# Epoch 4/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3173 - accuracy: 0.8870 - val_loss: 0.3343 - val_accuracy: 0.8842
# Epoch 5/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3000 - accuracy: 0.8930 - val_loss: 0.3291 - val_accuracy: 0.8824
# Epoch 6/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2833 - accuracy: 0.8992 - val_loss: 0.3280 - val_accuracy: 0.8820
# Epoch 7/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2705 - accuracy: 0.9038 - val_loss: 0.3211 - val_accuracy: 0.8860
# Epoch 8/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2589 - accuracy: 0.9085 - val_loss: 0.3279 - val_accuracy: 0.8822
# Epoch 9/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2479 - accuracy: 0.9117 - val_loss: 0.3143 - val_accuracy: 0.8880
# Epoch 10/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2378 - accuracy: 0.9154 - val_loss: 0.3118 - val_accuracy: 0.8904
# Epoch 1/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4773 - accuracy: 0.8334 - val_loss: 0.4142 - val_accuracy: 0.8550
# Epoch 2/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3495 - accuracy: 0.8735 - val_loss: 0.3645 - val_accuracy: 0.8768
# Epoch 3/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3049 - accuracy: 0.8897 - val_loss: 0.4443 - val_accuracy: 0.8496
# Epoch 4/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2766 - accuracy: 0.8991 - val_loss: 0.3562 - val_accuracy: 0.8810
# Epoch 5/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2548 - accuracy: 0.9067 - val_loss: 0.3536 - val_accuracy: 0.8904
# Epoch 6/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2351 - accuracy: 0.9149 - val_loss: 0.3679 - val_accuracy: 0.8884
# Epoch 7/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2210 - accuracy: 0.9201 - val_loss: 0.4240 - val_accuracy: 0.8740

# %% [markdown]
# Let's plot the results

# %%
for learning_rate, history in zip(learning_rates, histories):
    print("Learning rate:", learning_rate)
    plot_learning_curves(history)
# Out:
# Learning rate: 0.0001
# Learning rate: 0.01
# Learning rate: 0.1

# %% [markdown]
# Note that the learning rate influence significantly the training phase. That behavior suggests that is crucial to validate the hyper-parameters to obtain good results.

# %% [markdown]
# ### GRID Search:
#
# Since a deep net has many hyperparameters, in order to find the best ones, we have to consider all the possible combinations of all of the possible values. One common method to perform this complex task is Grid-Search.
# Given a set of values for each hyper-parameter, Grid-Search will build a model on each parameter combination possible. It iterates through every parameter combination and stores a model for each combination. Finally, the model that obtained the best result on the validation set will be select.
#
# In order to perfrom Grid-Search we will use GridSearchCV method from scikit-learn.

# %% [markdown]
# Let's Create a build_model() function that takes two arguments, n_units and learning_rate, and builds, compiles and returns a model with the given number of of neurons and the given learning rate.
# In order to limit the time demends of the proces we will consider only this two hyper-paramters and a small 3 layer model.

# %%
def build_model(n_units=30, learning_rate=1e-3):
  model = keras.models.Sequential([keras.layers.Flatten(input_shape=[28, 28]),keras.layers.Dense(n_units, activation="relu"),keras.layers.Dense(10, activation="softmax")])
  model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=learning_rate),
              metrics=["accuracy"])
  
  return model
 #To complete:
  #HINT: the function has to build the model with 3 layers:
  #- a Flatten layer to convert each 28x28 image to a single row 
  #- a Danse layer composed of n_units and that exploits Relu activation function 
  #- the output layer that uses the softmax activation function
  #Then, has to be defined how the model will be compiled.
    
#Create a keras.wrappers.scikit_learn.KerasRegressor and pass the build_model 
#function to the constructor. This gives you a Scikit-Learn compatible predictor
keras_reg = keras.wrappers.scikit_learn.KerasRegressor(build_model)

# %% [markdown]
# Let's define the lists of hyper-parameters' values. Also in this case, we use a very limited size lists, but in a real-world scenario a reasonable amount of possible values should be considered (try to add some values and check how much the time required to perform the Grid-Search increases)

# %%
param_distribs = {
    "n_units": [10,50,100],                         # To_complete: insert a few (2 or 3) reasonable values  
    "learning_rate": [5e-2, 1e-3, 5e-4]                             # To_complete: insert a few (2 or 3) reasonable values
}
    
    #Check how much increase the time required to perform GRID search increasing
    #the number of the values for each hyper-parameter.

# %% [markdown]
# Use a sklearn.model_selection.GridSearchCV to search the hyperparameter space of your KerasRegressor

# %%
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(keras_reg, param_distribs)

# %% [markdown]
# Run the Grid-Search

# %%
grid_search.fit(X_train_scaled, y_train, epochs=10, #The number of epochs can be modified (check what happens by increasing it) 
                  validation_data=(X_valid_scaled, y_valid))
# Out:
# Epoch 1/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.5586 - accuracy: 0.7972 - val_loss: 0.4363 - val_accuracy: 0.8428
# Epoch 2/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.4258 - accuracy: 0.8482 - val_loss: 0.4123 - val_accuracy: 0.8506
# Epoch 3/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.3996 - accuracy: 0.8564 - val_loss: 0.4043 - val_accuracy: 0.8602
# Epoch 4/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.3875 - accuracy: 0.8604 - val_loss: 0.4275 - val_accuracy: 0.8498
# Epoch 5/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.3751 - accuracy: 0.8651 - val_loss: 0.3957 - val_accuracy: 0.8602
# Epoch 6/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.3704 - accuracy: 0.8655 - val_loss: 0.3982 - val_accuracy: 0.8628
# Epoch 7/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.3630 - accuracy: 0.8682 - val_loss: 0.4049 - val_accuracy: 0.8596
# Epoch 8/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.3587 - accuracy: 0.8685 - val_loss: 0.4240 - val_accuracy: 0.8584
# Epoch 9/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.3526 - accuracy: 0.8715 - val_loss: 0.4123 - val_accuracy: 0.8608
# Epoch 10/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.3498 - accuracy: 0.8727 - val_loss: 0.4274 - val_accuracy: 0.8504
# 344/344 [==============================] - 0s 1ms/step - loss: 0.4373 - accuracy: 0.8405
# Epoch 1/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.5388 - accuracy: 0.8094 - val_loss: 0.4535 - val_accuracy: 0.8354
# Epoch 2/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.4259 - accuracy: 0.8459 - val_loss: 0.4056 - val_accuracy: 0.8494
# Epoch 3/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.4010 - accuracy: 0.8536 - val_loss: 0.3926 - val_accuracy: 0.8590
# Epoch 4/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.3858 - accuracy: 0.8592 - val_loss: 0.4149 - val_accuracy: 0.8518
# Epoch 5/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.3748 - accuracy: 0.8622 - val_loss: 0.3875 - val_accuracy: 0.8600
# Epoch 6/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.3680 - accuracy: 0.8661 - val_loss: 0.3838 - val_accuracy: 0.8600
# Epoch 7/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.3591 - accuracy: 0.8688 - val_loss: 0.3997 - val_accuracy: 0.8538
# Epoch 8/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.3537 - accuracy: 0.8699 - val_loss: 0.3881 - val_accuracy: 0.8586
# Epoch 9/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.3489 - accuracy: 0.8716 - val_loss: 0.3882 - val_accuracy: 0.8594
# Epoch 10/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.3443 - accuracy: 0.8741 - val_loss: 0.4104 - val_accuracy: 0.8514
# 344/344 [==============================] - 0s 1ms/step - loss: 0.4348 - accuracy: 0.8474
# Epoch 1/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.5387 - accuracy: 0.8117 - val_loss: 0.4374 - val_accuracy: 0.8432
# Epoch 2/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.4264 - accuracy: 0.8478 - val_loss: 0.4259 - val_accuracy: 0.8516
# Epoch 3/10
# 1375/1375 [==============================] - 2s 1ms/step - loss: 0.4016 - accuracy: 0.8531 - val_loss: 0.4062 - val_accuracy: 0.8628
# Epoch 4/10
# 1191/1375 [========================>.....] - ETA: 0s - loss: 0.3866 - accuracy: 0.8598
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-8db9fefb7112> in <module>()
#       1 grid_search.fit(X_train_scaled, y_train, epochs=10, #The number of epochs can be modified (check what happens by increasing it)
# ----> 2                   validation_data=(X_valid_scaled, y_valid))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# -> 1151         evaluate_candidates(ParameterGrid(self.param_grid))
#    1152
#    1153
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     687                                for parameters, (train, test)
#     688                                in product(candidate_params,
# --> 689                                           cv.split(X, y, groups)))
#     690
#     691                 if len(out) < 1:
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# -> 1007             while self.dispatch_one_batch(iterator):
#    1008                 pass
#    1009
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     513             estimator.fit(X_train, **fit_params)
#     514         else:
# --> 515             estimator.fit(X_train, y_train, **fit_params)
#     516
#     517     except Exception as e:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/wrappers/scikit_learn.py in fit(self, x, y, **kwargs)
#     164     fit_args.update(kwargs)
#     165
# --> 166     history = self.model.fit(x, y, **fit_args)
#     167
#     168     return history
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     783                 batch_size=batch_size):
#     784               callbacks.on_train_batch_begin(step)
# --> 785               tmp_logs = train_function(iterator)
#     786               # Catch OutOfRangeError for Datasets of unknown size.
#     787               # This blocks until the batch has finished executing.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2417     """Calls a graph function specialized to the inputs."""
#    2418     with self._lock:
# -> 2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
#    2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    2735           *args, **kwargs)
#    2736
# -> 2737     cache_key = self._cache_key(args, kwargs)
#    2738
#    2739     try:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _cache_key(self, args, kwargs, include_tensor_ranks_only)
#    2633
#    2634     return CacheKey(
# -> 2635         _make_input_signature_hashable(input_signature), parent_graph,
#    2636         device_functions, colocation_stack, in_cross_replica_context,
#    2637         xla_context_id)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _make_input_signature_hashable(elem, variable_map)
#     104   if isinstance(elem, tuple):
#     105     return tuple(map(lambda e: _make_input_signature_hashable(e, variable_map),
# --> 106                      elem))
#     107
#     108   # If the element is not hashable, assume it is a weakref to a variable
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in <lambda>(e)
#     103   # TODO(slebedev): consider using nest.
#     104   if isinstance(elem, tuple):
# --> 105     return tuple(map(lambda e: _make_input_signature_hashable(e, variable_map),
#     106                      elem))
#     107
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _make_input_signature_hashable(elem, variable_map)
#     104   if isinstance(elem, tuple):
#     105     return tuple(map(lambda e: _make_input_signature_hashable(e, variable_map),
# --> 106                      elem))
#     107
#     108   # If the element is not hashable, assume it is a weakref to a variable
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in <lambda>(e)
#     103   # TODO(slebedev): consider using nest.
#     104   if isinstance(elem, tuple):
# --> 105     return tuple(map(lambda e: _make_input_signature_hashable(e, variable_map),
#     106                      elem))
#     107
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _make_input_signature_hashable(elem, variable_map)
#     109   # and return the dtype & shape. Else, simply return the element
#     110   try:
# --> 111     hash(elem)
#     112   except TypeError:
#     113     assert isinstance(elem, weakref.ReferenceType)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/type_spec.py in __hash__(self)
#     270
#     271   def __hash__(self):
# --> 272     return hash(self.__get_cmp_key())
#     273
#     274   def __reduce__(self):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/type_spec.py in __get_cmp_key(self)
#     308     """Returns a hashable eq-comparable key for `self`."""
#     309     # TODO(b/133606651): Decide whether to cache this value.
# --> 310     return (type(self), self.__make_cmp_key(self._serialize()))
#     311
#     312   def __make_cmp_key(self, value):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/type_spec.py in __make_cmp_key(self, value)
#     325       ])
#     326     if isinstance(value, tuple):
# --> 327       return tuple([self.__make_cmp_key(v) for v in value])
#     328     if isinstance(value, list):
#     329       return (list, tuple([self.__make_cmp_key(v) for v in value]))
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/type_spec.py in <listcomp>(.0)
#     325       ])
#     326     if isinstance(value, tuple):
# --> 327       return tuple([self.__make_cmp_key(v) for v in value])
#     328     if isinstance(value, list):
#     329       return (list, tuple([self.__make_cmp_key(v) for v in value]))
#
# KeyboardInterrupt:

# %% [markdown]
# Print the best hyper-parameters, and evealuate the best model on the test set.

# %%
print(grid_search.best_params_)

model = grid_search.best_estimator_.model
model.evaluate(X_test_scaled, y_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-139-81733eda72e0> in <module>()
# ----> 1 print(grid_search.best_params_)
#       2
#       3 model = grid_search.best_estimator_.model
#       4 model.evaluate(X_test_scaled, y_test)
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'
